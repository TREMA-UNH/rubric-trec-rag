# %% [markdown]
# # RUBRIC@ TREC RAG 24
#
#
# **RUBRIC evaluation result analysis**
#
# ### Augmentation Task
#
#
# This notebook is part of the RUBRIC-trec-rag repository:
# <https://github.com/TREMA-UNH/rubric-trec-rag>
#
# Data Files available from the Online Appendix:  <https://trec-car.cs.unh.edu/rubric-trec-rag24/index.html>
#
# **Installation:**
#
# 1. check out the respository
# 2. install `nix` from <https://nixos.org/download/>  (not NixOS!)
# 3. follow instructions in repository [readme](https://github.com/TREMA-UNH/rubric-trec-rag/)
#
# **Usage:**
#
# 4. configure python environment with dependencies by calling
# ```
#     nix develop
# ```
# 5. start jupyter notebook server with
# ```
#     jupyter notebook
# ```
# 6. open this notebook and run all cells

# %%
import exam_pp
import rubric_trec_rag
from pathlib import Path
import numpy
import pandas as pd
import scipy

from exam_pp.exam_cover_metric import *
from scipy.stats._result_classes import TtestResult

from rubric_trec_rag.export_rag_gen_as_run import *
from exam_pp.exam_evaluation import *
# Out:
# [nltk_data] Downloading package stopwords to /home/dietz/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/dietz/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Device = None; BATCH_SIZE = 1

# %%
DATA=Path("./data")
promptclass="QuestionSelfRatedUnanswerablePromptWithChoices"

rubric_final_gen=DATA / "questions-rate--rubric-rag24-gen.jsonl.gz"
rubric_final_auggen=DATA / "questions-rate--rubric-rag24-auggen.jsonl.gz"
rubric_final_retrieval=DATA / "questions-rate--rubric-rag24-retrieval.jsonl.gz"

rubric_final = rubric_final_gen


ungraded_base = plot_file = rubric_final.with_name(f"{rubric_final.stem}")

runs = rubric_final.with_name(f"{rubric_final.stem}-runs")
qrels = rubric_final.with_suffix(".qrel")
export_file = rubric_final.with_suffix(".export.tsv")
all_leaderboard_file = rubric_final.with_suffix(".leaderboard.tsv")
archive = rubric_final.with_suffix(".results.tar.gz")

runs, qrels, export_file, all_leaderboard_file, archive
# Out:
# (PosixPath('data/questions-rate--rubric-rag24-gen.jsonl-runs'),
#  PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.qrel'),
#  PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.export.tsv'),
#  PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.leaderboard.tsv'),
#  PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.results.tar.gz'))

# %%
rubric_final
# Out:
# PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.gz')

# %%
# obtain rubric graded files
# (to overwrite old files, remove the `-nc` option and re-run)

# !wget -nc https://trec-car.cs.unh.edu/rubric-trec-rag24/questions-rate--rubric-rag24-auggen.jsonl.gz -O {rubric_final_auggen}
# !wget -nc https://trec-car.cs.unh.edu/rubric-trec-rag24/questions-rate--rubric-rag24-gen.jsonl.gz -O {rubric_final_gen}
# !wget -nc https://trec-car.cs.unh.edu/rubric-trec-rag24/questions-rate--rubric-rag24-retrieval.jsonl.gz -O {rubric_final_retrieval}
# Out:
# File ‘data/questions-rate--rubric-rag24-auggen.jsonl.gz’ already there; not retrieving.
# File ‘data/questions-rate--rubric-rag24-gen.jsonl.gz’ already there; not retrieving.
# File ‘data/questions-rate--rubric-rag24-retrieval.jsonl.gz’ already there; not retrieving.

# %%
# num graded queries
# !zcat {rubric_final} | wc -l
# Out:
# 301

# %% [markdown]
# # Load Rubric data

# %%
def exam_grades(model, prompt_class, question_set, exam_graded_file):
    '''
    Load grades and paragraphs from RUBRIC internal file format
    '''
    grade_filter = GradeFilter(model_name=model, prompt_class = prompt_class, is_self_rated=None, min_self_rating=None, question_set=question_set, prompt_type=get_prompt_type_from_prompt_class(prompt_class))
    exam_input_file=exam_graded_file
    query_paragraphs:List[QueryWithFullParagraphList] = parseQueryWithFullParagraphs(exam_input_file)
    return query_paragraphs

# %% [markdown]
# # Open graded file and inspect exam grades
#
# Json Example
#
# ```json
# [
#   "2024-145979",
#   [
#     {
#       "paragraph_id": "b504cab1b522f7906c0abb44c30f4cd7",
#       "text": "Vicarious trauma refers to the emotional and psychological impact experienced by individuals who are indirectly exposed to others' traumatic experiences.",
#       "paragraph_data": {
#         "judgments": [],
#         "rankings": [
#           {
#             "method": "according-useful",
#             "paragraphId": "b504cab1b522f7906c0abb44c30f4cd7",
#             "queryId": "2024-145979",
#             "rank": 1,
#             "score": 1.0
#           }
#         ]
#       },
#       "exam_grades": [
#         {
#           "correctAnswered": [
#             "2024-145979/ccc217319305b84a7a73db16d1d3d52d",
#             "2024-145979/899180b0ca4b7daf548fc3b1d74c6917",
#             "2024-145979/36b39eb1b546f06082fa99a07883a4ca",
#             "2024-145979/06ff2a4f1e4869fe26dd034679403bad",
#             "2024-145979/9b20f574516d894404136a8829b535d9",
#             "2024-145979/dae1cd1ab183da5804311e764b1987d0",
#             "2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a",
#             "2024-145979/40ee972ed1298a8b6e4894467c1a9dc4",
#             "2024-145979/c8271d09bfd0b289d93ea501b129f308"
#           ],
#           "wrongAnswered": [
#             "2024-145979/87c4cb0bd3430af2fc39ee05959e6abb"
#           ],
#           "answers": [
#             [
#               "2024-145979/ccc217319305b84a7a73db16d1d3d52d",
#               "5\nExplanation: The passage provides a clear and comprehensive overview of vicarious trauma, including common symptoms such as emotional exhaustion, detachment, and cynicism. The passage also explains the potential long-term effects of
#  vicarious trauma on individuals, making it a highly relevant and accurate answer to the question."
#             ],
#             [
#               "2024-145979/899180b0ca4b7daf548fc3b1d74c6917",
#               "5\nExplanation: The passage provides a clear and accurate definition of vicarious trauma, which is distinct from burnout. It explains that vicarious trauma is the emotional and psychological impact experienced by individuals who are in
# directly exposed to others' traumatic experiences. This answer is highly relevant, complete, and accurate, as it directly addresses the question and provides a clear distinction between vicarious trauma and burnout."
#             ],
#             [
#               "2024-145979/87c4cb0bd3430af2fc39ee05959e6abb",
#               "The passage does not directly address the question, but it does provide some relevant information about vicarious trauma and its effects. The passage does not provide specific coping strategies for dealing with vicarious trauma. Howeve
# r, it does suggest that it is important to recognize the impact of vicarious trauma and to seek support when needed. The passage also mentions that vicarious trauma can be mitigated by developing a sense of control and by engaging in activities that
# promote a sense of well-being. Overall, the passage provides some"
#             ],
#             [
#               "2024-145979/36b39eb1b546f06082fa99a07883a4ca",
#               "5. The passage directly addresses the impact of vicarious trauma on personal relationships outside of work, providing a clear and accurate answer to the question. It highlights the potential for vicarious trauma to affect relationships with family and friends, as well as the importance of self-care and support networks in mitigating its effects. The passage provides a comprehensive and relevant answer to the question."
#             ],
#             [
#               "2024-145979/06ff2a4f1e4869fe26dd034679403bad",
#               "5\nExplanation: The passage clearly states that professional therapy or counseling is usually recommended for those experiencing vicarious trauma, as it can help them process and cope with their emotions. The passage also mentions that vicarious trauma can have long-lasting effects if left untreated. The answer is highly relevant, complete, and accurate, earning a rating of 5."
#             ],
#             [
#               "2024-145979/9b20f574516d894404136a8829b535d9",
#               "4\nExplanation: The passage provides some relevant information about vicarious trauma, such as its definition and the potential effects on individuals. However, it does not offer specific strategies or recommendations for organizations to better support individuals who may be experiencing vicarious trauma. Therefore, the answer is mostly relevant and complete but may have minor gaps or inaccuracies."
#             ],
#             [
#               "2024-145979/dae1cd1ab183da5804311e764b1987d0",
#               "4\nExplanation: The passage discusses the importance of self-care for individuals who have been exposed to others' traumatic experiences, but it does not provide a comprehensive overview of the role of self-care in coping with vicarious trauma. It mentions that self-care can help individuals develop resilience and reduce the risk of burnout, but it does not elaborate on the specific ways in which self-care can be used to cope with vicarious trauma. The passage also does not provide any concrete examples or strategies for incorporating"
#             ],
#             [
#               "2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a",
#               "4\nExplanation: The passage does not directly answer the question, but it provides some relevant information about the concept of vicarious trauma and its effects. It mentions that vicarious trauma can occur in various settings, including healthcare, social services, and education. However, it does not specifically mention industries or professions that are more prone to vicarious trauma. Therefore, the answer is rated as 4, indicating that the passage is mostly relevant and complete but lacks specific information on the topic."
#             ],
#             [
#               "2024-145979/40ee972ed1298a8b6e4894467c1a9dc4",
#               "4. The passage provides a general understanding of vicarious trauma and its impact, but it does not specifically address how individuals can identify their own triggers for vicarious trauma. The reader would need to look elsewhere for more detailed information on this topic. However, the passage does provide a good foundation for understanding the concept of vicarious trauma, which is a good starting point for further exploration."
#             ],
#             [
#               "2024-145979/c8271d09bfd0b289d93ea501b129f308",
#               "5\nExplanation: The passage provides a comprehensive overview of resources available for preventing and managing vicarious trauma in the workplace. It highlights the importance of creating a supportive work environment, providing training and education, and encouraging open communication. The passage also mentions the role of leadership and management in addressing vicarious trauma, as well as the need for ongoing support and resources for affected employees. Overall, the passage provides a thorough and accurate answer to the question."
#             ]
#           ],
#           "llm": "meta-llama/Meta-Llama-3-8B-Instruct",
#           "llm_options": {},
#           "exam_ratio": 0.9,
#           "prompt_info": {
#             "prompt_class": "QuestionSelfRatedUnanswerablePromptWithChoices",
#             "orig_prompt_class": "unknown",
#             "prompt_style": "Can the question be answered based on the available context? Choose one",
#             "context_first": false,
#             "check_unanswerable": true,
#             "check_answer_key": false,
#             "is_self_rated": true,
#             "is_self_rater_tolerant": true
#           },
#            "self_ratings": [
#             {
#               "question_id": "2024-145979/ccc217319305b84a7a73db16d1d3d52d",
#               "self_rating": 5
#             },
#             {
#               "question_id": "2024-145979/899180b0ca4b7daf548fc3b1d74c6917",
#               "self_rating": 5
#             },
#             {
#               "question_id": "2024-145979/87c4cb0bd3430af2fc39ee05959e6abb",
#               "self_rating": 0
#             },
#             {
#               "question_id": "2024-145979/36b39eb1b546f06082fa99a07883a4ca",
#               "self_rating": 5
#             },
#             {
#               "question_id": "2024-145979/06ff2a4f1e4869fe26dd034679403bad",
#               "self_rating": 5
#             },
#             {
#               "question_id": "2024-145979/9b20f574516d894404136a8829b535d9",
#               "self_rating": 4
#             },
#             {
#               "question_id": "2024-145979/dae1cd1ab183da5804311e764b1987d0",
#               "self_rating": 4
#             },
#             {
#               "question_id": "2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a",
#               "self_rating": 4
#             },
#             {
#               "question_id": "2024-145979/40ee972ed1298a8b6e4894467c1a9dc4",
#               "self_rating": 4
#             },
#             {
#               "question_id": "2024-145979/c8271d09bfd0b289d93ea501b129f308",
#               "self_rating": 5
#             }
#           ],
#           "prompt_type": "question"
#         }
#       ]
#     },
#
# ```

# %%
print(f"rubric file: {rubric_final}")
# load grades from rubric file
examgrades = exam_grades(model=None, prompt_class=promptclass, question_set="question-bank", exam_graded_file=rubric_final)
# Out:
# rubric file: data/questions-rate--rubric-rag24-gen.jsonl.gz

# %%
# example for inspecting RUBRIC grading results

for result in examgrades[0:1]: # just first query
    result: QueryWithFullParagraphList
    queryId=result.queryId
    paragraphs=result.paragraphs
    print(f"query = {result.queryId}")

    for paragraph in paragraphs[0:10]:  # just first ten paragraphs
        paragraph: FullParagraphData
        paragraph_id = paragraph.paragraph_id
        text = paragraph.text
        # judgments = paragraph.paragraph_data.judgments if paragraph.paragraph_data else []  # manual judgments currently not available for RAG
        rankings = paragraph.paragraph_data.rankings if paragraph.paragraph_data else [] # which system retrieved this paragraph?
        print("\n")
        print(paragraph_id)
        print(text)
        print(rankings)
        for grades in paragraph.exam_grades:
            grades: ExamGrades
            # self_ratings are the numerical grade (0-5) for each question-style nugget
            # answers are the raw output we received from the grading LLM
            for (r, a) in zip(grades.self_ratings, grades.answers): 
                print(r.question_id, r.self_rating, 'raw_answer: ',a)
# Out:
# query = 2024-145979
#
#
# b504cab1b522f7906c0abb44c30f4cd7
# Vicarious trauma refers to the emotional and psychological impact experienced by individuals who are indirectly exposed to others' traumatic experiences.
# [ParagraphRankingEntry(method='according-useful', paragraphId='b504cab1b522f7906c0abb44c30f4cd7', queryId='2024-145979', rank=1, score=1.0)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 0 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '0')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 4 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '4')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 4 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '4')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# 8521da7819bf27e36acf5756ff242ead
# This can occur through situations where one witnesses or hears about life-threatening events or the death of another person, leading to a profound and shocking reaction akin to adopting the trauma as one's own.
# [ParagraphRankingEntry(method='according-useful', paragraphId='8521da7819bf27e36acf5756ff242ead', queryId='2024-145979', rank=2, score=0.5)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 0 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '0')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', "akin to adopting the trauma as one's own")
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 4 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '4')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 4 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '4')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# dda43296f08841e028309e36bcc238c4
# The trauma typically results in changed personal beliefs about oneself and the world.
# [ParagraphRankingEntry(method='according-useful', paragraphId='dda43296f08841e028309e36bcc238c4', queryId='2024-145979', rank=3, score=0.3333333333333333)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 0 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '0')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 0 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '0')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# 8268a511d6acaddfd258373ff7c3a9bb
# Those in caring professions, such as doctors, surgeons, nurses, therapists, police officers, and journalists, are most susceptible.
# [ParagraphRankingEntry(method='according-useful', paragraphId='8268a511d6acaddfd258373ff7c3a9bb', queryId='2024-145979', rank=4, score=0.25)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 0 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '0')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 0 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '0')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 5 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '5')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# c22ed847d5a8651083a4fba55498f740
# Additionally, having close relationships with trauma survivors can also cause vicarious trauma.
# [ParagraphRankingEntry(method='according-useful', paragraphId='c22ed847d5a8651083a4fba55498f740', queryId='2024-145979', rank=5, score=0.2)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 0 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '0')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 4 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '4')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# f8f71503071aa59deac9af1f3f1fb8a0
# Individuals experiencing vicarious trauma are at significant risk of developing mental health issues, including anxiety, clinical depression, post-traumatic stress disorder (PTSD), and addictions.
# [ParagraphRankingEntry(method='according-useful', paragraphId='f8f71503071aa59deac9af1f3f1fb8a0', queryId='2024-145979', rank=6, score=0.16666666666666666)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 4 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '4')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 0 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '0')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 4 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '4')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# 71363c580ae97acfef72af00679e995c
# Symptoms manifest in various ways, affecting emotions, thoughts, physiological responses, behavior, and relationships.
# [ParagraphRankingEntry(method='according-useful', paragraphId='71363c580ae97acfef72af00679e995c', queryId='2024-145979', rank=7, score=0.14285714285714285)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 0 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '0')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 4 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '4')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# 208c39a4c5209ffecdaae0e338e1509d
# Emotionally, sufferers may feel anxious, sad, irritable, or numb.
# [ParagraphRankingEntry(method='according-useful', paragraphId='208c39a4c5209ffecdaae0e338e1509d', queryId='2024-145979', rank=8, score=0.125)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 4 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '4')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 0 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '0')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# eff55b6b5b834c97554667cb3357a985
# Cognitive symptoms include a jaded view of the world, cynicism, and persistent worry.
# [ParagraphRankingEntry(method='according-useful', paragraphId='eff55b6b5b834c97554667cb3357a985', queryId='2024-145979', rank=9, score=0.1111111111111111)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 4 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '4')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 0 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '0')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')
#
#
# 3cc408a6bcb719a832a84f825d1d280b
# Physiological symptoms may present as headaches, stomach pain, and chronic exhaustion.
# [ParagraphRankingEntry(method='according-useful', paragraphId='3cc408a6bcb719a832a84f825d1d280b', queryId='2024-145979', rank=10, score=0.1)]
# 2024-145979/ccc217319305b84a7a73db16d1d3d52d 4 raw_answer:  ('2024-145979/ccc217319305b84a7a73db16d1d3d52d', '4')
# 2024-145979/899180b0ca4b7daf548fc3b1d74c6917 0 raw_answer:  ('2024-145979/899180b0ca4b7daf548fc3b1d74c6917', '0')
# 2024-145979/87c4cb0bd3430af2fc39ee05959e6abb 0 raw_answer:  ('2024-145979/87c4cb0bd3430af2fc39ee05959e6abb', '0')
# 2024-145979/36b39eb1b546f06082fa99a07883a4ca 0 raw_answer:  ('2024-145979/36b39eb1b546f06082fa99a07883a4ca', '0')
# 2024-145979/06ff2a4f1e4869fe26dd034679403bad 0 raw_answer:  ('2024-145979/06ff2a4f1e4869fe26dd034679403bad', '0')
# 2024-145979/9b20f574516d894404136a8829b535d9 0 raw_answer:  ('2024-145979/9b20f574516d894404136a8829b535d9', '0')
# 2024-145979/dae1cd1ab183da5804311e764b1987d0 0 raw_answer:  ('2024-145979/dae1cd1ab183da5804311e764b1987d0', '0')
# 2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a 0 raw_answer:  ('2024-145979/bd8cc33b944bc940b9ed6a49c0f4502a', '0')
# 2024-145979/40ee972ed1298a8b6e4894467c1a9dc4 0 raw_answer:  ('2024-145979/40ee972ed1298a8b6e4894467c1a9dc4', '0')
# 2024-145979/c8271d09bfd0b289d93ea501b129f308 0 raw_answer:  ('2024-145979/c8271d09bfd0b289d93ea501b129f308', '0')

# %%
# rubric  json schema
print("queryId, list of...")

print(FullParagraphData.schema_json(indent=2))
# Out:
# queryId, list of...
# {
#   "title": "FullParagraphData",
#   "type": "object",
#   "properties": {
#     "paragraph_id": {
#       "title": "Paragraph Id",
#       "type": "string"
#     },
#     "text": {
#       "title": "Text",
#       "type": "string"
#     },
#     "paragraph": {
#       "title": "Paragraph"
#     },
#     "paragraph_data": {
#       "$ref": "#/definitions/ParagraphData"
#     },
#     "exam_grades": {
#       "title": "Exam Grades",
#       "type": "array",
#       "items": {
#         "$ref": "#/definitions/ExamGrades"
#       }
#     },
#     "grades": {
#       "title": "Grades",
#       "type": "array",
#       "items": {
#         "$ref": "#/definitions/Grades"
#       }
#     }
#   },
#   "required": [
#     "paragraph_id",
#     "text",
#     "paragraph_data"
#   ],
#   "definitions": {
#     "Judgment": {
#       "title": "Judgment",
#       "type": "object",
#       "properties": {
#         "paragraphId": {
#           "title": "Paragraphid",
#           "type": "string"
#         },
#         "query": {
#           "title": "Query",
#           "type": "string"
#         },
#         "relevance": {
#           "title": "Relevance",
#           "type": "integer"
#         },
#         "titleQuery": {
#           "title": "Titlequery",
#           "type": "string"
#         }
#       },
#       "required": [
#         "paragraphId",
#         "query",
#         "relevance",
#         "titleQuery"
#       ]
#     },
#     "ParagraphRankingEntry": {
#       "title": "ParagraphRankingEntry",
#       "type": "object",
#       "properties": {
#         "method": {
#           "title": "Method",
#           "type": "string"
#         },
#         "paragraphId": {
#           "title": "Paragraphid",
#           "type": "string"
#         },
#         "queryId": {
#           "title": "Queryid",
#           "type": "string"
#         },
#         "rank": {
#           "title": "Rank",
#           "type": "integer"
#         },
#         "score": {
#           "title": "Score",
#           "type": "number"
#         }
#       },
#       "required": [
#         "method",
#         "paragraphId",
#         "queryId",
#         "rank",
#         "score"
#       ]
#     },
#     "ParagraphData": {
#       "title": "ParagraphData",
#       "type": "object",
#       "properties": {
#         "judgments": {
#           "title": "Judgments",
#           "type": "array",
#           "items": {
#             "$ref": "#/definitions/Judgment"
#           }
#         },
#         "rankings": {
#           "title": "Rankings",
#           "type": "array",
#           "items": {
#             "$ref": "#/definitions/ParagraphRankingEntry"
#           }
#         }
#       },
#       "required": [
#         "judgments",
#         "rankings"
#       ]
#     },
#     "SelfRating": {
#       "title": "SelfRating",
#       "type": "object",
#       "properties": {
#         "question_id": {
#           "title": "Question Id",
#           "type": "string"
#         },
#         "nugget_id": {
#           "title": "Nugget Id",
#           "type": "string"
#         },
#         "self_rating": {
#           "title": "Self Rating",
#           "type": "integer"
#         }
#       },
#       "required": [
#         "self_rating"
#       ]
#     },
#     "ExamGrades": {
#       "title": "ExamGrades",
#       "type": "object",
#       "properties": {
#         "correctAnswered": {
#           "title": "Correctanswered",
#           "type": "array",
#           "items": {
#             "type": "string"
#           }
#         },
#         "wrongAnswered": {
#           "title": "Wronganswered",
#           "type": "array",
#           "items": {
#             "type": "string"
#           }
#         },
#         "answers": {
#           "title": "Answers",
#           "type": "array",
#           "items": {
#             "type": "array",
#             "minItems": 2,
#             "maxItems": 2,
#             "items": [
#               {
#                 "type": "string"
#               },
#               {
#                 "type": "string"
#               }
#             ]
#           }
#         },
#         "llm": {
#           "title": "Llm",
#           "type": "string"
#         },
#         "llm_options": {
#           "title": "Llm Options",
#           "type": "object"
#         },
#         "exam_ratio": {
#           "title": "Exam Ratio",
#           "type": "number"
#         },
#         "prompt_info": {
#           "title": "Prompt Info",
#           "type": "object"
#         },
#         "self_ratings": {
#           "title": "Self Ratings",
#           "type": "array",
#           "items": {
#             "$ref": "#/definitions/SelfRating"
#           }
#         },
#         "prompt_type": {
#           "title": "Prompt Type",
#           "type": "string"
#         }
#       },
#       "required": [
#         "correctAnswered",
#         "wrongAnswered",
#         "answers",
#         "llm",
#         "llm_options",
#         "exam_ratio"
#       ]
#     },
#     "Grades": {
#       "title": "Grades",
#       "type": "object",
#       "properties": {
#         "correctAnswered": {
#           "title": "Correctanswered",
#           "type": "boolean"
#         },
#         "answer": {
#           "title": "Answer",
#           "type": "string"
#         },
#         "llm": {
#           "title": "Llm",
#           "type": "string"
#         },
#         "llm_options": {
#           "title": "Llm Options",
#           "type": "object"
#         },
#         "prompt_info": {
#           "title": "Prompt Info",
#           "type": "object"
#         },
#         "self_ratings": {
#           "title": "Self Ratings",
#           "type": "integer"
#         },
#         "prompt_type": {
#           "title": "Prompt Type",
#           "type": "string"
#         }
#       },
#       "required": [
#         "correctAnswered",
#         "answer",
#         "llm",
#         "llm_options"
#       ]
#     }
#   }
# }

# %% [markdown]
# # Extract leaderboards
#
#
# RUBRIC-cover:
# 1. run `export_rag_rubric_cover_leaderboard`
#
#
# RUBRIC-qrels:
# 1. convert run files from rubric files  (`export_rag_gen_as_run_main`)
# 2. produce leaderboard with trec_eval
#
#
# Manual production of RUBRIC-qrels
# 1. convert run files from rubric files (`export_rag_gen_as_run_main`)
# 2. export qrels file  (`export_qrels`)
# 3. run trec_eval (or similar) manually

# %% [markdown]
# ### Convert run files
#
# (this may take a moment)

# %%
def export_rag_gen_as_run_main(rubric_graded_file, run_out):
    # now emit the input files for RUBRIC/EXAM
    rubric_data:List[QueryWithFullParagraphList] 
    # rubric_data = parseQueryWithFullParagraphs(rubric_graded_file)
    rubric_data = examgrades

    run_entry_per_method:Dict[str,List[ParagraphRankingEntry]] = defaultdict(list)

    # collect ranking entries
    for entry in rubric_data:
        for para in entry.paragraphs:
            for rankEntry in para.paragraph_data.rankings:
                run_entry_per_method[rankEntry.method].append(rankEntry)

    runDir:Path = run_out
    
    # create dir if necessary
    runDir.mkdir(exist_ok=True)
    
    # delete old files
    for file in runDir.iterdir():
        if file.is_file():
            file.unlink()

    # write as trec_eval compatible run files
    for method,rankEntries in run_entry_per_method.items():
        sorted_ranking_entries = sorted(rankEntries, key=attrgetter('queryId','rank'))
        unique_sorted_ranking_entries = remove_duplicates_by_key(sorted_ranking_entries, key_func=lambda r: (r.queryId, r.paragraphId))
        
        runFile = runDir/(f'{method}.run')
        if(runFile.exists()):
            print(f"Overwriting {runFile.absolute()}")
        else: 
            print(f"Exporting to {runFile.absolute()}")
        export_run_file(run_file=runFile, ranking_entries=unique_sorted_ranking_entries)

    return unique_sorted_ranking_entries

# %%
res = export_rag_gen_as_run_main(rubric_final, runs)
res[0:10]
# Out:
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/according-useful.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/account-born.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/tiny-e-mail.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/activity-financial.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/agreement-helpful.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/assume-trip.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/product-lover.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/violate-train.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/basis-veteran.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/gently-tennis.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/shadow-remember.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/battery-frequently.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/beginning-french.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/cooking-every.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/current-scream.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/elect-fifth.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/honest-darkness.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/length-very.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/space-traffic.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/would-regime.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/business-square.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/press-wipe.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/capacity-indian.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/climb-housing.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/coat-sequence.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/competition-tell.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/computer-resource.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/concern-read.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/crime-road.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/develop-space.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/proof-hunting.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/differ-able.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/elsewhere-define.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/minor-channel.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/discover-universe.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/double-open.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/myth-emphasis.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/effectively-college.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/elite-democrat.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/encounter-belong.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/expansion-petrol.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/flow-cheap.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/justice-tonight.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/force-bring.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/frame-permit.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/garlic-squeeze.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/listen-responsible.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/right-moon.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/girl-cousin.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/golf-species.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/quite-specialist.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/literally-championship.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/ground-gently.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/head-represent.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/historic-adviser.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/hunting-fishing.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/instructor-setting.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/issue-shop.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/journey-lazy.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/king-calculate.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/left-latin.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/lesson-limited.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/purchase-survivor.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/unless-happen.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/main-debt.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/port-reform.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/massive-hard.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/massive-luck.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/mental-refer.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/pilot-competitor.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/multiple-contact.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/ongoing-stare.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/palm-long-term.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/suspect-feed.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/participate-factory.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/pepper-highlight.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/steady-merely.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/percentage-feeling.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/quality-courage.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/rank-friendly.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/react-moral.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/understanding-passenger.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/relation-loan.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/talent-evaluation.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/rose-canadian.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/somewhere-holy.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/string-player.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/tram-begin.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/tremendous-whatever.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/unusual-pain.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/wisdom-trust.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/wooden-comedy.run
# Exporting to /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl-runs/write-quarterback.run
# [ParagraphRankingEntry(method='write-quarterback', paragraphId='b4ccdce24e62b20c88fb7ff8bd0ef5b3', queryId='2024-105741', rank=1, score=1.0),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='58898b905e777322d2950bd1ec978ff7', queryId='2024-105741', rank=2, score=0.5),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='5aeae99d061a3cc90af2b9762e0d93a4', queryId='2024-105741', rank=3, score=0.3333333333333333),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='4ac7a65b80a9a2b686d6cbae641d5272', queryId='2024-109837', rank=1, score=1.0),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='5c7a9ea8d4315e9d4d225f3f5f5c4cc2', queryId='2024-109837', rank=2, score=0.5),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='b8e0f35d84a812a48fcf5901a300ef20', queryId='2024-109837', rank=3, score=0.3333333333333333),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='1d4f3ca443b1456789a7a03651b74dfd', queryId='2024-109837', rank=4, score=0.25),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='117aea800511f100bbb9aff25b136380', queryId='2024-109837', rank=5, score=0.2),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='ba5907ba8f93cac638a36cad4e0af4e3', queryId='2024-109837', rank=6, score=0.16666666666666666),
#  ParagraphRankingEntry(method='write-quarterback', paragraphId='f44ec7f91ec6cdce556d2ded5dc07866', queryId='2024-111331', rank=1, score=1.0)]

# %% [markdown]
# # Export Leaderboard

# %%
# If multiple grading configuration are in the same rubric file, 
# then use this grade filter to select a particular LLM model (e.g. "google/flan-t5-large")
# or grading prompt (e.g. "QuestionSelfRatedUnanswerablePromptWithChoices" or "NuggetSelfRatedPrompt")
# or question set (e.g. "question-bank")
# or prompt_type (e.g "question", "nugget", or "direct")

grade_filter = GradeFilter(model_name=None, prompt_class = promptclass, is_self_rated=None, min_self_rating=None, question_set="question-bank", prompt_type=get_prompt_type_from_prompt_class(promptclass))

# %% [markdown]
# ## Export qrels for RUBRIC-Qrels or manual trec_eval

# %%
# function to export qrels
def export_qrels(examgrades, qrel_out, prompt_class, model):
    grade_filter = GradeFilter(model_name=model, prompt_class = prompt_class, is_self_rated=None, min_self_rating=None, question_set="question-bank", prompt_type=get_prompt_type_from_prompt_class(prompt_class))

    exam_pp.exam_evaluation.export_qrels(query_paragraphs=examgrades
             , qrel_out_file=qrel_out
             , grade_filter=grade_filter
             , use_query_facets=False
             , use_ratings=True  # answerability grades
             , direct_grading=False
             )

# %%
# perform export
export_qrels(examgrades, qrels, promptclass,model=None)

# %%
# Verify exported qrel content

# !head {qrels}
# Out:
# 2024-145979 0 b504cab1b522f7906c0abb44c30f4cd7 4
# 2024-145979 0 8521da7819bf27e36acf5756ff242ead 4
# 2024-145979 0 dda43296f08841e028309e36bcc238c4 0
# 2024-145979 0 8268a511d6acaddfd258373ff7c3a9bb 5
# 2024-145979 0 c22ed847d5a8651083a4fba55498f740 4
# 2024-145979 0 f8f71503071aa59deac9af1f3f1fb8a0 4
# 2024-145979 0 71363c580ae97acfef72af00679e995c 4
# 2024-145979 0 208c39a4c5209ffecdaae0e338e1509d 4
# 2024-145979 0 eff55b6b5b834c97554667cb3357a985 4
# 2024-145979 0 3cc408a6bcb719a832a84f825d1d280b 4

# %% [markdown]
# ## Export individual RUBRIC leaderboards
#
# You can skip forward to the next section, if you don't want to create additional leaderboards.

# %%
minrating = 4

cover_board= rubric_final.with_name(f"{rubric_final.stem}-cover-{minrating}").with_suffix(".tsv")
qrels_board= rubric_final.with_name(f"{rubric_final.stem}-qrels-{minrating}").with_suffix(".tsv")

# %%
# functions to export a RUBRIC-Cover Leaderboard

# Alternatives to produce leaderboard
# python -O -m exam_pp.exam_evaluation $DATA/$rubric_final --question-set question-bank --prompt-class $promptclass --min-self-rating $minrating --leaderboard-out $DATA/$cover_board.tsv

# exam_pp.exam_evaluation.run_leaderboard(leaderboard_file=cover_board
#                         , grade_filter=grade_filter
#                         , query_paragraphs=examgrades
#                         , min_self_rating=minrating
#                         , leaderboard_sort=None
#                         )


def cover_leaderboard(leaderboard_file, examgrades, minrating, leaderboard_sort:Optional[str])-> Dict[str,exam_pp.exam_cover_metric.ExamCoverEvalsDict]:
    '''
    Computes query-wise RUBRIC-cover score
    writes a tsv file with mean and stderr to `leaderboard_file`
    returns a dictionary of MethodName to `ExamCoverEvalsDict`
    '''
    exam_factory = ExamCoverScorerFactory(grade_filter=grade_filter, min_self_rating=minrating)
    resultsPerMethod:Dict[str, ExamCoverEvals] = compute_exam_cover_scores(examgrades, exam_factory=exam_factory)
    export_leaderboard_table(leaderboard_out=leaderboard_file, evals= list(resultsPerMethod.values()), sortBy=leaderboard_sort)
    return resultsPerMethod

# %%
# function to export a RUBRIC-qrels leaderboard
from exam_pp.exam_run_trec_eval import *

def qrels_leaderboard(leaderboard_file, run_dir, qrels,  examgrades, minrating, trec_eval_metric, leaderboard_sort:Optional[str])-> Dict[str,exam_pp.exam_cover_metric.ExamCoverEvalsDict]:
    resultsPerMethod:Dict[str, ExamCoverEvals]
    
    trec_eval_out =run_trec_eval_variance(run_dir=run_dir, qrels=qrels, min_level=minrating, trec_eval_metric=trec_eval_metric)
    trec_eval_parsed=parse_trec_eval_variance(trec_eval_out)
    resultsPerMethod = compute_exam_qrels_scores(trec_eval_parsed)
    
    # exam_leaderboard_correlation.print_leaderboard_eval(evals = list(resultsPerMethod.values()), grade_filter=grade_filter)
    export_leaderboard_table(leaderboard_out=leaderboard_file, evals= list(resultsPerMethod.values()), sortBy=leaderboard_sort)
    return resultsPerMethod

# %%
# Because TREC RAG segment Ids contain `#`
# which is considered a reserved comment char in trec_eval, 
# we have to patch all generated run/qrel files to get rid of it.

import subprocess

print(runs)
subprocess.run(["find", runs, "-type", "f", "-exec", "sed", "-i", "s/#//g", "{}", "+"])

print(qrels)
subprocess.run(["sed", "-i", "s/#//g", qrels])
# Out:
# data/questions-rate--rubric-rag24-gen.jsonl-runs
# data/questions-rate--rubric-rag24-gen.jsonl.qrel
# CompletedProcess(args=['sed', '-i', 's/#//g', PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.qrel')], returncode=0)

# %%
# example of individual leaderboards

# cover_result = cover_leaderboard(leaderboard_file=cover_board, examgrades=examgrades,minrating= minrating, leaderboard_sort=None)
qrel_result = qrels_leaderboard(leaderboard_file=qrels_board, run_dir=runs, qrels = qrels
                                , examgrades=examgrades, minrating= minrating, trec_eval_metric="P.20"
                                , leaderboard_sort=None)
# Out:
# Running trec_eval command:
# for f in *.run; do  res=`trec_eval -n -c -q -m P.20  -l 4  /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl.qrel $f`; echo "$f $res"; done
# in directory: data/questions-rate--rubric-rag24-gen.jsonl-runs
# OVERALL EXAM-qrels method _overall_: avg examScores 0.00 +/0 0.000
# OVERALL EXAM-qrels method according-useful: avg examScores 0.45 +/0 0.010
# OVERALL EXAM-qrels method account-born: avg examScores 0.15 +/0 0.006
# OVERALL EXAM-qrels method activity-financial: avg examScores 0.28 +/0 0.007
# OVERALL EXAM-qrels method agreement-helpful: avg examScores 0.21 +/0 0.008
# OVERALL EXAM-qrels method assume-trip: avg examScores 0.25 +/0 0.010
# OVERALL EXAM-qrels method basis-veteran: avg examScores 0.16 +/0 0.005
# OVERALL EXAM-qrels method battery-frequently: avg examScores 0.28 +/0 0.008
# OVERALL EXAM-qrels method beginning-french: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method business-square: avg examScores 0.17 +/0 0.006
# OVERALL EXAM-qrels method capacity-indian: avg examScores 0.24 +/0 0.007
# OVERALL EXAM-qrels method climb-housing: avg examScores 0.44 +/0 0.010
# OVERALL EXAM-qrels method coat-sequence: avg examScores 0.34 +/0 0.007
# OVERALL EXAM-qrels method competition-tell: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method computer-resource: avg examScores 0.25 +/0 0.007
# OVERALL EXAM-qrels method concern-read: avg examScores 0.23 +/0 0.006
# OVERALL EXAM-qrels method cooking-every: avg examScores 0.11 +/0 0.006
# OVERALL EXAM-qrels method crime-road: avg examScores 0.44 +/0 0.010
# OVERALL EXAM-qrels method current-scream: avg examScores 0.08 +/0 0.005
# OVERALL EXAM-qrels method develop-space: avg examScores 0.10 +/0 0.004
# OVERALL EXAM-qrels method differ-able: avg examScores 0.18 +/0 0.009
# OVERALL EXAM-qrels method discover-universe: avg examScores 0.43 +/0 0.012
# OVERALL EXAM-qrels method double-open: avg examScores 0.17 +/0 0.007
# OVERALL EXAM-qrels method effectively-college: avg examScores 0.45 +/0 0.012
# OVERALL EXAM-qrels method elect-fifth: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method elite-democrat: avg examScores 0.13 +/0 0.005
# OVERALL EXAM-qrels method elsewhere-define: avg examScores 0.13 +/0 0.005
# OVERALL EXAM-qrels method encounter-belong: avg examScores 0.32 +/0 0.011
# OVERALL EXAM-qrels method expansion-petrol: avg examScores 0.49 +/0 0.012
# OVERALL EXAM-qrels method flow-cheap: avg examScores 0.09 +/0 0.004
# OVERALL EXAM-qrels method force-bring: avg examScores 0.12 +/0 0.007
# OVERALL EXAM-qrels method frame-permit: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method garlic-squeeze: avg examScores 0.13 +/0 0.004
# OVERALL EXAM-qrels method gently-tennis: avg examScores 0.16 +/0 0.005
# OVERALL EXAM-qrels method girl-cousin: avg examScores 0.10 +/0 0.005
# OVERALL EXAM-qrels method golf-species: avg examScores 0.44 +/0 0.012
# OVERALL EXAM-qrels method ground-gently: avg examScores 0.25 +/0 0.009
# OVERALL EXAM-qrels method head-represent: avg examScores 0.31 +/0 0.013
# OVERALL EXAM-qrels method historic-adviser: avg examScores 0.26 +/0 0.010
# OVERALL EXAM-qrels method honest-darkness: avg examScores 0.11 +/0 0.006
# OVERALL EXAM-qrels method hunting-fishing: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method instructor-setting: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method issue-shop: avg examScores 0.28 +/0 0.006
# OVERALL EXAM-qrels method journey-lazy: avg examScores 0.12 +/0 0.006
# OVERALL EXAM-qrels method justice-tonight: avg examScores 0.19 +/0 0.008
# OVERALL EXAM-qrels method king-calculate: avg examScores 0.25 +/0 0.007
# OVERALL EXAM-qrels method left-latin: avg examScores 0.18 +/0 0.007
# OVERALL EXAM-qrels method length-very: avg examScores 0.09 +/0 0.005
# OVERALL EXAM-qrels method lesson-limited: avg examScores 0.24 +/0 0.007
# OVERALL EXAM-qrels method listen-responsible: avg examScores 0.12 +/0 0.004
# OVERALL EXAM-qrels method literally-championship: avg examScores 0.43 +/0 0.012
# OVERALL EXAM-qrels method main-debt: avg examScores 0.10 +/0 0.005
# OVERALL EXAM-qrels method massive-hard: avg examScores 0.18 +/0 0.005
# OVERALL EXAM-qrels method massive-luck: avg examScores 0.22 +/0 0.008
# OVERALL EXAM-qrels method mental-refer: avg examScores 0.28 +/0 0.016
# OVERALL EXAM-qrels method minor-channel: avg examScores 0.17 +/0 0.009
# OVERALL EXAM-qrels method multiple-contact: avg examScores 0.28 +/0 0.006
# OVERALL EXAM-qrels method myth-emphasis: avg examScores 0.16 +/0 0.008
# OVERALL EXAM-qrels method ongoing-stare: avg examScores 0.52 +/0 0.012
# OVERALL EXAM-qrels method palm-long-term: avg examScores 0.51 +/0 0.012
# OVERALL EXAM-qrels method participate-factory: avg examScores 0.44 +/0 0.010
# OVERALL EXAM-qrels method pepper-highlight: avg examScores 0.08 +/0 0.006
# OVERALL EXAM-qrels method percentage-feeling: avg examScores 0.11 +/0 0.005
# OVERALL EXAM-qrels method pilot-competitor: avg examScores 0.28 +/0 0.016
# OVERALL EXAM-qrels method port-reform: avg examScores 0.11 +/0 0.005
# OVERALL EXAM-qrels method press-wipe: avg examScores 0.17 +/0 0.006
# OVERALL EXAM-qrels method product-lover: avg examScores 0.24 +/0 0.009
# OVERALL EXAM-qrels method proof-hunting: avg examScores 0.09 +/0 0.004
# OVERALL EXAM-qrels method purchase-survivor: avg examScores 0.42 +/0 0.010
# OVERALL EXAM-qrels method quality-courage: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method quite-specialist: avg examScores 0.42 +/0 0.012
# OVERALL EXAM-qrels method rank-friendly: avg examScores 0.27 +/0 0.007
# OVERALL EXAM-qrels method react-moral: avg examScores 0.33 +/0 0.008
# OVERALL EXAM-qrels method relation-loan: avg examScores 0.11 +/0 0.009
# OVERALL EXAM-qrels method right-moon: avg examScores 0.10 +/0 0.008
# OVERALL EXAM-qrels method rose-canadian: avg examScores 0.27 +/0 0.007
# OVERALL EXAM-qrels method shadow-remember: avg examScores 0.16 +/0 0.005
# OVERALL EXAM-qrels method somewhere-holy: avg examScores 0.16 +/0 0.007
# OVERALL EXAM-qrels method space-traffic: avg examScores 0.17 +/0 0.009
# OVERALL EXAM-qrels method steady-merely: avg examScores 0.09 +/0 0.005
# OVERALL EXAM-qrels method string-player: avg examScores 0.16 +/0 0.007
# OVERALL EXAM-qrels method suspect-feed: avg examScores 0.51 +/0 0.012
# OVERALL EXAM-qrels method talent-evaluation: avg examScores 0.16 +/0 0.009
# OVERALL EXAM-qrels method tiny-e-mail: avg examScores 0.16 +/0 0.007
# OVERALL EXAM-qrels method tram-begin: avg examScores 0.23 +/0 0.011
# OVERALL EXAM-qrels method tremendous-whatever: avg examScores 0.46 +/0 0.010
# OVERALL EXAM-qrels method understanding-passenger: avg examScores 0.17 +/0 0.009
# OVERALL EXAM-qrels method unless-happen: avg examScores 0.44 +/0 0.012
# OVERALL EXAM-qrels method unusual-pain: avg examScores 0.21 +/0 0.006
# OVERALL EXAM-qrels method violate-train: avg examScores 0.25 +/0 0.010
# OVERALL EXAM-qrels method wisdom-trust: avg examScores 0.17 +/0 0.005
# OVERALL EXAM-qrels method wooden-comedy: avg examScores 0.24 +/0 0.009
# OVERALL EXAM-qrels method would-regime: avg examScores 0.11 +/0 0.005
# OVERALL EXAM-qrels method write-quarterback: avg examScores 0.21 +/0 0.006
# ExamCover Leaderboard written to data/questions-rate--rubric-rag24-gen.tsv

# %%
# Verify RUBRIC-qrels leaderboard output
# !cat {qrels_board}
# Out:
# method	ExamCover	+/-	std-err
# _overall_	0.000	+/-	0.000
# according-useful	0.448	+/-	0.010
# account-born	0.145	+/-	0.006
# activity-financial	0.285	+/-	0.007
# agreement-helpful	0.208	+/-	0.008
# assume-trip	0.253	+/-	0.010
# basis-veteran	0.159	+/-	0.005
# battery-frequently	0.276	+/-	0.008
# beginning-french	0.051	+/-	0.003
# business-square	0.173	+/-	0.006
# capacity-indian	0.242	+/-	0.007
# climb-housing	0.440	+/-	0.010
# coat-sequence	0.342	+/-	0.007
# competition-tell	0.052	+/-	0.003
# computer-resource	0.248	+/-	0.007
# concern-read	0.228	+/-	0.006
# cooking-every	0.112	+/-	0.006
# crime-road	0.441	+/-	0.010
# current-scream	0.083	+/-	0.005
# develop-space	0.097	+/-	0.004
# differ-able	0.177	+/-	0.009
# discover-universe	0.429	+/-	0.012
# double-open	0.170	+/-	0.007
# effectively-college	0.448	+/-	0.012
# elect-fifth	0.049	+/-	0.003
# elite-democrat	0.132	+/-	0.005
# elsewhere-define	0.133	+/-	0.005
# encounter-belong	0.320	+/-	0.011
# expansion-petrol	0.487	+/-	0.012
# flow-cheap	0.090	+/-	0.004
# force-bring	0.115	+/-	0.007
# frame-permit	0.273	+/-	0.006
# garlic-squeeze	0.129	+/-	0.004
# gently-tennis	0.155	+/-	0.005
# girl-cousin	0.102	+/-	0.005
# golf-species	0.435	+/-	0.012
# ground-gently	0.247	+/-	0.009
# head-represent	0.314	+/-	0.013
# historic-adviser	0.257	+/-	0.010
# honest-darkness	0.109	+/-	0.006
# hunting-fishing	0.272	+/-	0.006
# instructor-setting	0.266	+/-	0.006
# issue-shop	0.275	+/-	0.006
# journey-lazy	0.118	+/-	0.006
# justice-tonight	0.189	+/-	0.008
# king-calculate	0.253	+/-	0.007
# left-latin	0.183	+/-	0.007
# length-very	0.086	+/-	0.005
# lesson-limited	0.237	+/-	0.007
# listen-responsible	0.119	+/-	0.004
# literally-championship	0.433	+/-	0.012
# main-debt	0.102	+/-	0.005
# massive-hard	0.185	+/-	0.005
# massive-luck	0.221	+/-	0.008
# mental-refer	0.284	+/-	0.016
# minor-channel	0.172	+/-	0.009
# multiple-contact	0.283	+/-	0.006
# myth-emphasis	0.164	+/-	0.008
# ongoing-stare	0.521	+/-	0.012
# palm-long-term	0.512	+/-	0.012
# participate-factory	0.441	+/-	0.010
# pepper-highlight	0.082	+/-	0.006
# percentage-feeling	0.105	+/-	0.005
# pilot-competitor	0.284	+/-	0.016
# port-reform	0.113	+/-	0.005
# press-wipe	0.173	+/-	0.006
# product-lover	0.237	+/-	0.009
# proof-hunting	0.093	+/-	0.004
# purchase-survivor	0.424	+/-	0.010
# quality-courage	0.050	+/-	0.003
# quite-specialist	0.420	+/-	0.012
# rank-friendly	0.268	+/-	0.007
# react-moral	0.328	+/-	0.008
# relation-loan	0.112	+/-	0.009
# right-moon	0.101	+/-	0.008
# rose-canadian	0.265	+/-	0.007
# shadow-remember	0.157	+/-	0.005
# somewhere-holy	0.159	+/-	0.007
# space-traffic	0.166	+/-	0.009
# steady-merely	0.086	+/-	0.005
# string-player	0.159	+/-	0.007
# suspect-feed	0.512	+/-	0.012
# talent-evaluation	0.164	+/-	0.009
# tiny-e-mail	0.159	+/-	0.007
# tram-begin	0.225	+/-	0.011
# tremendous-whatever	0.461	+/-	0.010
# understanding-passenger	0.171	+/-	0.009
# unless-happen	0.435	+/-	0.012
# unusual-pain	0.208	+/-	0.006
# violate-train	0.253	+/-	0.010
# wisdom-trust	0.173	+/-	0.005
# wooden-comedy	0.242	+/-	0.009
# would-regime	0.110	+/-	0.005
# write-quarterback	0.212	+/-	0.006

# %%
# example of computing mean +/- stderr per method

from exam_pp.exam_cover_metric import *
from scipy.stats._result_classes import TtestResult

def leaderboard_mean_stderr(leaderboard, method):
    '''
    Mean and stderr of a method (=system/run) under a RUBRIC-measure
    '''
    mean,stderr=systemMeanStderr(leaderboard[method].examCoverPerQuery.values())
    return mean,stderr

@dataclass
class ComparisonResult():
    mean1:float
    mean2:float
    ttest_result:TtestResult
    mean_diff:float

def leaderboard_paired_ttest(leaderboard, method1, method2):
    '''
    Are two methods (=systems/runs) significantly different under a RUBRIC-measure?
    '''
    values1 = numpy.array(list(leaderboard[method1].examCoverPerQuery.values()))
    values2 = numpy.array(list(leaderboard[method2].examCoverPerQuery.values()))

    mean1 = numpy.mean(values1)
    mean2 = numpy.mean(values2)
    t = scipy.stats.ttest_rel(values1, values2)
    mean_diff = numpy.mean(values1 - values2)

    return ComparisonResult(mean1=mean1, mean2=mean2, ttest_result=t,  mean_diff=mean_diff)

# %%
# example on how to access results and compute statistics

leader_result = qrel_result
# leader_result = cover_result

print(leader_result.keys())

method1 = list(leader_result.keys())[1] # 'space-traffic'
method2 = list(leader_result.keys())[7] #'pepper-highlight'

mean1,stderr1=leaderboard_mean_stderr(leader_result, method1)
mean2,stderr2=leaderboard_mean_stderr(leader_result, method2)
comparison=leaderboard_paired_ttest(leader_result, method1, method2)

print(f"{method1}: {mean1} +/- {stderr1}")
print(f"{method2}: {mean2} +/- {stderr2}")
print(f"{method1}: {comparison.mean1}   vs {method2}:{comparison.mean2}")
print(f"avg 1 better? {comparison.mean_diff}")
print(f"paired ttest: {comparison.ttest_result}")
# Out:
# dict_keys(['_overall_', 'according-useful', 'account-born', 'activity-financial', 'agreement-helpful', 'assume-trip', 'basis-veteran', 'battery-frequently', 'beginning-french', 'business-square', 'capacity-indian', 'climb-housing', 'coat-sequence', 'competition-tell', 'computer-resource', 'concern-read', 'cooking-every', 'crime-road', 'current-scream', 'develop-space', 'differ-able', 'discover-universe', 'double-open', 'effectively-college', 'elect-fifth', 'elite-democrat', 'elsewhere-define', 'encounter-belong', 'expansion-petrol', 'flow-cheap', 'force-bring', 'frame-permit', 'garlic-squeeze', 'gently-tennis', 'girl-cousin', 'golf-species', 'ground-gently', 'head-represent', 'historic-adviser', 'honest-darkness', 'hunting-fishing', 'instructor-setting', 'issue-shop', 'journey-lazy', 'justice-tonight', 'king-calculate', 'left-latin', 'length-very', 'lesson-limited', 'listen-responsible', 'literally-championship', 'main-debt', 'massive-hard', 'massive-luck', 'mental-refer', 'minor-channel', 'multiple-contact', 'myth-emphasis', 'ongoing-stare', 'palm-long-term', 'participate-factory', 'pepper-highlight', 'percentage-feeling', 'pilot-competitor', 'port-reform', 'press-wipe', 'product-lover', 'proof-hunting', 'purchase-survivor', 'quality-courage', 'quite-specialist', 'rank-friendly', 'react-moral', 'relation-loan', 'right-moon', 'rose-canadian', 'shadow-remember', 'somewhere-holy', 'space-traffic', 'steady-merely', 'string-player', 'suspect-feed', 'talent-evaluation', 'tiny-e-mail', 'tram-begin', 'tremendous-whatever', 'understanding-passenger', 'unless-happen', 'unusual-pain', 'violate-train', 'wisdom-trust', 'wooden-comedy', 'would-regime', 'write-quarterback'])
# according-useful: 0.4478405315614618 +/- 0.010216968680045218
# battery-frequently: 0.2760797342192691 +/- 0.008384300895738717
# according-useful: 0.4478405315614618   vs battery-frequently:0.27607973421926907
# avg 1 better? 0.17176079734219268
# paired ttest: TtestResult(statistic=20.43425054850302, pvalue=9.314142283486609e-59, df=300)

# %% [markdown]
# ## Compute TREC RAG Leaderboards
#
# We are computing five RUBRIC-leaderboards which we contribute in the TREC RAG'24 Evaluatuation

# %%
cover_result1 = cover_leaderboard(leaderboard_file=rubric_final.with_suffix(".cover-1.tsv"), examgrades=examgrades,minrating= 1, leaderboard_sort=None)
cover_result4 = cover_leaderboard(leaderboard_file=rubric_final.with_suffix(".cover-4.tsv"), examgrades=examgrades,minrating= 4, leaderboard_sort=None)
cover_result5 = cover_leaderboard(leaderboard_file=rubric_final.with_suffix(".cover-5.tsv"), examgrades=examgrades,minrating= 5, leaderboard_sort=None)

qrel_result_ndcg = qrels_leaderboard(leaderboard_file=rubric_final.with_suffix(".qrels-ndcg.tsv"), run_dir=runs, qrels = qrels
                                , examgrades=examgrades, minrating= 1, trec_eval_metric="ndcg_cut.20"
                                , leaderboard_sort=None)
qrel_result1 = qrels_leaderboard(leaderboard_file=rubric_final.with_suffix(".qrels-1.tsv"), run_dir=runs, qrels = qrels
                                , examgrades=examgrades, minrating= 1, trec_eval_metric="P.20"
                                , leaderboard_sort=None)
qrel_result4 = qrels_leaderboard(leaderboard_file=rubric_final.with_suffix(".qrels-4.tsv"), run_dir=runs, qrels = qrels
                                , examgrades=examgrades, minrating= 4, trec_eval_metric="P.20"
                                , leaderboard_sort=None)
qrel_result5 = qrels_leaderboard(leaderboard_file=rubric_final.with_suffix(".qrels-5.tsv"), run_dir=runs, qrels = qrels
                                , examgrades=examgrades, minrating= 5, trec_eval_metric="P.20"
                                , leaderboard_sort=None)
# Out:
# 2024-145979, overall ratio 1.0
# 2024-36935, overall ratio 1.0
# 2024-216592, overall ratio 1.0
# 2024-32912, overall ratio 1.0
# 2024-153051, overall ratio 1.0
# 2024-128784, overall ratio 1.0
# 2024-134815, overall ratio 1.0
# 2024-79081, overall ratio 1.0
# 2024-42497, overall ratio 0.8
# 2024-158743, overall ratio 1.0
# 2024-214630, overall ratio 1.0
# 2024-143869, overall ratio 1.0
# 2024-173513, overall ratio 1.0
# 2024-133137, overall ratio 0.9
# 2024-36155, overall ratio 1.0
# 2024-12875, overall ratio 1.0
# 2024-41477, overall ratio 1.0
# 2024-29941, overall ratio 0.9
# 2024-137315, overall ratio 1.0
# 2024-43037, overall ratio 1.0
# 2024-43983, overall ratio 1.0
# 2024-214126, overall ratio 1.0
# 2024-161461, overall ratio 1.0
# 2024-220140, overall ratio 1.0
# 2024-224279, overall ratio 1.0
# 2024-134629, overall ratio 1.0
# 2024-69711, overall ratio 0.9
# 2024-5957, overall ratio 1.0
# 2024-214096, overall ratio 1.0
# 2024-219624, overall ratio 1.0
# 2024-220058, overall ratio 1.0
# 2024-73340, overall ratio 0.9
# 2024-43972, overall ratio 1.0
# 2024-26688, overall ratio 1.0
# 2024-44060, overall ratio 1.0
# 2024-96359, overall ratio 1.0
# 2024-147909, overall ratio 1.0
# 2024-41918, overall ratio 1.0
# 2024-142395, overall ratio 1.0
# 2024-41610, overall ratio 1.0
# 2024-36857, overall ratio 1.0
# 2024-40863, overall ratio 1.0
# 2024-35284, overall ratio 1.0
# 2024-160253, overall ratio 1.0
# 2024-136156, overall ratio 1.0
# 2024-173795, overall ratio 1.0
# 2024-127653, overall ratio 1.0
# 2024-88894, overall ratio 0.9
# 2024-113646, overall ratio 1.0
# 2024-126056, overall ratio 1.0
# 2024-225026, overall ratio 1.0
# 2024-41960, overall ratio 1.0
# 2024-43905, overall ratio 1.0
# 2024-33359, overall ratio 1.0
# 2024-22886, overall ratio 1.0
# 2024-35269, overall ratio 1.0
# 2024-25032, overall ratio 1.0
# 2024-206384, overall ratio 1.0
# 2024-135747, overall ratio 1.0
# 2024-114095, overall ratio 1.0
# 2024-41198, overall ratio 1.0
# 2024-76908, overall ratio 0.9
# 2024-219626, overall ratio 1.0
# 2024-73918, overall ratio 0.9
# 2024-219661, overall ratio 1.0
# 2024-223914, overall ratio 1.0
# 2024-37173, overall ratio 1.0
# 2024-219824, overall ratio 1.0
# 2024-44059, overall ratio 1.0
# 2024-32796, overall ratio 1.0
# 2024-217279, overall ratio 1.0
# 2024-158261, overall ratio 0.9
# 2024-217241, overall ratio 1.0
# 2024-18963, overall ratio 1.0
# 2024-19025, overall ratio 1.0
# 2024-141577, overall ratio 1.0
# 2024-7058, overall ratio 1.0
# 2024-38461, overall ratio 1.0
# 2024-129925, overall ratio 1.0
# 2024-158677, overall ratio 1.0
# 2024-38379, overall ratio 1.0
# 2024-127288, overall ratio 1.0
# 2024-137182, overall ratio 1.0
# 2024-213469, overall ratio 1.0
# 2024-213817, overall ratio 1.0
# 2024-42781, overall ratio 0.9
# 2024-22900, overall ratio 1.0
# 2024-35620, overall ratio 1.0
# 2024-222481, overall ratio 1.0
# 2024-38611, overall ratio 1.0
# 2024-23680, overall ratio 1.0
# 2024-41849, overall ratio 1.0
# 2024-149459, overall ratio 1.0
# 2024-24226, overall ratio 1.0
# 2024-36302, overall ratio 1.0
# 2024-152259, overall ratio 1.0
# 2024-34582, overall ratio 1.0
# 2024-27366, overall ratio 1.0
# 2024-41796, overall ratio 1.0
# 2024-76647, overall ratio 1.0
# 2024-36338, overall ratio 1.0
# 2024-36672, overall ratio 1.0
# 2024-90454, overall ratio 1.0
# 2024-224926, overall ratio 1.0
# 2024-217812, overall ratio 1.0
# 2024-6778, overall ratio 1.0
# 2024-215952, overall ratio 1.0
# 2024-79154, overall ratio 1.0
# 2024-137667, overall ratio 0.9
# 2024-22410, overall ratio 1.0
# 2024-220307, overall ratio 0.9
# 2024-44329, overall ratio 1.0
# 2024-223358, overall ratio 1.0
# 2024-79113, overall ratio 1.0
# 2024-133810, overall ratio 1.0
# 2024-213978, overall ratio 1.0
# 2024-35320, overall ratio 1.0
# 2024-19947, overall ratio 1.0
# 2024-219698, overall ratio 1.0
# 2024-79129, overall ratio 1.0
# 2024-41465, overall ratio 1.0
# 2024-214052, overall ratio 1.0
# 2024-105741, overall ratio 1.0
# 2024-225247, overall ratio 1.0
# 2024-42376, overall ratio 1.0
# 2024-37531, overall ratio 0.8
# 2024-111506, overall ratio 1.0
# 2024-36131, overall ratio 1.0
# 2024-17909, overall ratio 1.0
# 2024-36186, overall ratio 1.0
# 2024-29182, overall ratio 1.0
# 2024-73921, overall ratio 1.0
# 2024-216231, overall ratio 1.0
# 2024-24022, overall ratio 1.0
# 2024-40724, overall ratio 1.0
# 2024-221429, overall ratio 1.0
# 2024-37596, overall ratio 1.0
# 2024-219631, overall ratio 1.0
# 2024-224710, overall ratio 1.0
# 2024-42645, overall ratio 1.0
# 2024-34521, overall ratio 1.0
# 2024-41334, overall ratio 1.0
# 2024-96063, overall ratio 1.0
# 2024-37470, overall ratio 1.0
# 2024-221278, overall ratio 1.0
# 2024-41464, overall ratio 1.0
# 2024-224621, overall ratio 1.0
# 2024-41563, overall ratio 1.0
# 2024-3824, overall ratio 1.0
# 2024-44754, overall ratio 1.0
# 2024-19454, overall ratio 1.0
# 2024-223499, overall ratio 1.0
# 2024-17605, overall ratio 1.0
# 2024-94706, overall ratio 1.0
# 2024-23862, overall ratio 1.0
# 2024-217496, overall ratio 1.0
# 2024-216957, overall ratio 1.0
# 2024-131116, overall ratio 1.0
# 2024-36741, overall ratio 1.0
# 2024-43684, overall ratio 1.0
# 2024-45185, overall ratio 1.0
# 2024-35834, overall ratio 1.0
# 2024-141280, overall ratio 0.9
# 2024-35506, overall ratio 1.0
# 2024-214257, overall ratio 0.9
# 2024-45474, overall ratio 1.0
# 2024-44024, overall ratio 1.0
# 2024-219271, overall ratio 1.0
# 2024-42163, overall ratio 1.0
# 2024-5992, overall ratio 1.0
# 2024-225389, overall ratio 1.0
# 2024-219385, overall ratio 0.8
# 2024-146077, overall ratio 1.0
# 2024-147273, overall ratio 1.0
# 2024-33466, overall ratio 1.0
# 2024-96485, overall ratio 1.0
# 2024-216598, overall ratio 1.0
# 2024-149261, overall ratio 1.0
# 2024-145295, overall ratio 1.0
# 2024-35227, overall ratio 1.0
# 2024-36355, overall ratio 1.0
# 2024-42556, overall ratio 1.0
# 2024-19448, overall ratio 1.0
# 2024-3653, overall ratio 1.0
# 2024-42195, overall ratio 1.0
# 2024-44048, overall ratio 0.9
# 2024-40831, overall ratio 1.0
# 2024-142330, overall ratio 1.0
# 2024-222465, overall ratio 1.0
# 2024-32534, overall ratio 0.9
# 2024-40868, overall ratio 1.0
# 2024-41077, overall ratio 1.0
# 2024-44544, overall ratio 1.0
# 2024-25195, overall ratio 1.0
# 2024-32856, overall ratio 1.0
# 2024-67021, overall ratio 1.0
# 2024-5675, overall ratio 0.8
# 2024-224063, overall ratio 0.9
# 2024-215090, overall ratio 1.0
# 2024-215256, overall ratio 1.0
# 2024-213855, overall ratio 1.0
# 2024-141993, overall ratio 1.0
# 2024-126414, overall ratio 1.0
# 2024-221836, overall ratio 1.0
# 2024-220794, overall ratio 1.0
# 2024-215044, overall ratio 1.0
# 2024-152817, overall ratio 1.0
# 2024-5809, overall ratio 1.0
# 2024-224960, overall ratio 1.0
# 2024-138052, overall ratio 1.0
# 2024-109837, overall ratio 1.0
# 2024-142125, overall ratio 1.0
# 2024-127349, overall ratio 1.0
# 2024-224701, overall ratio 1.0
# 2024-126326, overall ratio 1.0
# 2024-224013, overall ratio 0.9
# 2024-42464, overall ratio 1.0
# 2024-34595, overall ratio 1.0
# 2024-213491, overall ratio 1.0
# 2024-37566, overall ratio 1.0
# 2024-214744, overall ratio 1.0
# 2024-34710, overall ratio 0.9
# 2024-6587, overall ratio 1.0
# 2024-29222, overall ratio 1.0
# 2024-42738, overall ratio 1.0
# 2024-77150, overall ratio 1.0
# 2024-128311, overall ratio 1.0
# 2024-22919, overall ratio 1.0
# 2024-225531, overall ratio 0.9
# 2024-221442, overall ratio 1.0
# 2024-213789, overall ratio 1.0
# 2024-223094, overall ratio 0.9
# 2024-146893, overall ratio 1.0
# 2024-38428, overall ratio 1.0
# 2024-29936, overall ratio 1.0
# 2024-44001, overall ratio 1.0
# 2024-225456, overall ratio 1.0
# 2024-220679, overall ratio 1.0
# 2024-77099, overall ratio 1.0
# 2024-41711, overall ratio 1.0
# 2024-44065, overall ratio 1.0
# 2024-224226, overall ratio 1.0
# 2024-160888, overall ratio 1.0
# 2024-7532, overall ratio 1.0
# 2024-213901, overall ratio 1.0
# 2024-224399, overall ratio 1.0
# 2024-224207, overall ratio 1.0
# 2024-40996, overall ratio 1.0
# 2024-219896, overall ratio 1.0
# 2024-225150, overall ratio 1.0
# 2024-153070, overall ratio 1.0
# 2024-215094, overall ratio 1.0
# 2024-214333, overall ratio 1.0
# 2024-34583, overall ratio 1.0
# 2024-224339, overall ratio 1.0
# 2024-223829, overall ratio 1.0
# 2024-223855, overall ratio 1.0
# 2024-221022, overall ratio 1.0
# 2024-223382, overall ratio 1.0
# 2024-66937, overall ratio 1.0
# 2024-25003, overall ratio 1.0
# 2024-218590, overall ratio 1.0
# 2024-142084, overall ratio 1.0
# 2024-38986, overall ratio 0.9
# 2024-221364, overall ratio 1.0
# 2024-35596, overall ratio 1.0
# 2024-44005, overall ratio 1.0
# 2024-111331, overall ratio 0.9
# 2024-32502, overall ratio 1.0
# 2024-217582, overall ratio 1.0
# 2024-225223, overall ratio 1.0
# 2024-215833, overall ratio 1.0
# 2024-28144, overall ratio 1.0
# 2024-41576, overall ratio 0.9
# 2024-35485, overall ratio 1.0
# 2024-190455, overall ratio 1.0
# 2024-129062, overall ratio 1.0
# 2024-33513, overall ratio 1.0
# 2024-32817, overall ratio 1.0
# 2024-214483, overall ratio 1.0
# 2024-223345, overall ratio 0.9
# 2024-217488, overall ratio 1.0
# 2024-214467, overall ratio 1.0
# 2024-113215, overall ratio 1.0
# 2024-134964, overall ratio 1.0
# 2024-19562, overall ratio 1.0
# 2024-219563, overall ratio 1.0
# 2024-22172, overall ratio 1.0
# 2024-34927, overall ratio 1.0
# 2024-141453, overall ratio 1.0
# 2024-45494, overall ratio 1.0
# 2024-217827, overall ratio 1.0
# 2024-66915, overall ratio 1.0
# 2024-147917, overall ratio 1.0
# 2024-121840, overall ratio 1.0
# 2024-222696, overall ratio 1.0
# 2024-58819, overall ratio 1.0
# 2024-42014, overall ratio 1.0
# 2024-6862, overall ratio 1.0
# 2024-127266, overall ratio 1.0
# 2024-21669, overall ratio 1.0
# OVERALL N-EXAM@20 method _overall_: avg examScores 1.00 +/0 0.000
# OVERALL EXAM@20 method _overall_: avg examScores 0.99 +/0 0.002
# OVERALL N-EXAM@20 method according-useful: avg examScores 0.84 +/0 0.009
# OVERALL EXAM@20 method according-useful: avg examScores 0.83 +/0 0.009
# OVERALL N-EXAM@20 method account-born: avg examScores 0.63 +/0 0.014
# OVERALL EXAM@20 method account-born: avg examScores 0.62 +/0 0.014
# OVERALL N-EXAM@20 method tiny-e-mail: avg examScores 0.63 +/0 0.014
# OVERALL EXAM@20 method tiny-e-mail: avg examScores 0.63 +/0 0.014
# OVERALL N-EXAM@20 method activity-financial: avg examScores 0.78 +/0 0.011
# OVERALL EXAM@20 method activity-financial: avg examScores 0.77 +/0 0.011
# OVERALL N-EXAM@20 method agreement-helpful: avg examScores 0.71 +/0 0.013
# OVERALL EXAM@20 method agreement-helpful: avg examScores 0.71 +/0 0.013
# OVERALL N-EXAM@20 method assume-trip: avg examScores 0.72 +/0 0.012
# OVERALL EXAM@20 method assume-trip: avg examScores 0.72 +/0 0.012
# OVERALL N-EXAM@20 method product-lover: avg examScores 0.72 +/0 0.012
# OVERALL EXAM@20 method product-lover: avg examScores 0.72 +/0 0.012
# OVERALL N-EXAM@20 method violate-train: avg examScores 0.72 +/0 0.012
# OVERALL EXAM@20 method violate-train: avg examScores 0.72 +/0 0.012
# OVERALL N-EXAM@20 method basis-veteran: avg examScores 0.66 +/0 0.013
# OVERALL EXAM@20 method basis-veteran: avg examScores 0.65 +/0 0.013
# OVERALL N-EXAM@20 method gently-tennis: avg examScores 0.67 +/0 0.013
# OVERALL EXAM@20 method gently-tennis: avg examScores 0.66 +/0 0.013
# OVERALL N-EXAM@20 method shadow-remember: avg examScores 0.66 +/0 0.013
# OVERALL EXAM@20 method shadow-remember: avg examScores 0.66 +/0 0.013
# OVERALL N-EXAM@20 method battery-frequently: avg examScores 0.75 +/0 0.011
# OVERALL EXAM@20 method battery-frequently: avg examScores 0.75 +/0 0.012
# OVERALL N-EXAM@20 method beginning-french: avg examScores 0.52 +/0 0.016
# OVERALL EXAM@20 method beginning-french: avg examScores 0.52 +/0 0.016
# OVERALL N-EXAM@20 method cooking-every: avg examScores 0.60 +/0 0.015
# OVERALL EXAM@20 method cooking-every: avg examScores 0.60 +/0 0.015
# OVERALL N-EXAM@20 method current-scream: avg examScores 0.53 +/0 0.016
# OVERALL EXAM@20 method current-scream: avg examScores 0.52 +/0 0.016
# OVERALL N-EXAM@20 method elect-fifth: avg examScores 0.51 +/0 0.016
# OVERALL EXAM@20 method elect-fifth: avg examScores 0.50 +/0 0.016
# OVERALL N-EXAM@20 method honest-darkness: avg examScores 0.59 +/0 0.016
# OVERALL EXAM@20 method honest-darkness: avg examScores 0.59 +/0 0.016
# OVERALL N-EXAM@20 method length-very: avg examScores 0.54 +/0 0.016
# OVERALL EXAM@20 method length-very: avg examScores 0.53 +/0 0.016
# OVERALL N-EXAM@20 method space-traffic: avg examScores 0.62 +/0 0.016
# OVERALL EXAM@20 method space-traffic: avg examScores 0.62 +/0 0.016
# OVERALL N-EXAM@20 method would-regime: avg examScores 0.60 +/0 0.015
# OVERALL EXAM@20 method would-regime: avg examScores 0.59 +/0 0.015
# OVERALL N-EXAM@20 method business-square: avg examScores 0.69 +/0 0.013
# OVERALL EXAM@20 method business-square: avg examScores 0.68 +/0 0.013
# OVERALL N-EXAM@20 method press-wipe: avg examScores 0.69 +/0 0.013
# OVERALL EXAM@20 method press-wipe: avg examScores 0.68 +/0 0.013
# OVERALL N-EXAM@20 method capacity-indian: avg examScores 0.76 +/0 0.012
# OVERALL EXAM@20 method capacity-indian: avg examScores 0.75 +/0 0.012
# OVERALL N-EXAM@20 method climb-housing: avg examScores 0.83 +/0 0.009
# OVERALL EXAM@20 method climb-housing: avg examScores 0.82 +/0 0.009
# OVERALL N-EXAM@20 method coat-sequence: avg examScores 0.84 +/0 0.009
# OVERALL EXAM@20 method coat-sequence: avg examScores 0.83 +/0 0.009
# OVERALL N-EXAM@20 method competition-tell: avg examScores 0.49 +/0 0.016
# OVERALL EXAM@20 method competition-tell: avg examScores 0.49 +/0 0.016
# OVERALL N-EXAM@20 method computer-resource: avg examScores 0.74 +/0 0.012
# OVERALL EXAM@20 method computer-resource: avg examScores 0.74 +/0 0.012
# OVERALL N-EXAM@20 method concern-read: avg examScores 0.80 +/0 0.010
# OVERALL EXAM@20 method concern-read: avg examScores 0.79 +/0 0.010
# OVERALL N-EXAM@20 method crime-road: avg examScores 0.84 +/0 0.008
# OVERALL EXAM@20 method crime-road: avg examScores 0.83 +/0 0.009
# OVERALL N-EXAM@20 method develop-space: avg examScores 0.60 +/0 0.014
# OVERALL EXAM@20 method develop-space: avg examScores 0.59 +/0 0.015
# OVERALL N-EXAM@20 method proof-hunting: avg examScores 0.60 +/0 0.014
# OVERALL EXAM@20 method proof-hunting: avg examScores 0.60 +/0 0.014
# OVERALL N-EXAM@20 method differ-able: avg examScores 0.62 +/0 0.015
# OVERALL EXAM@20 method differ-able: avg examScores 0.62 +/0 0.015
# OVERALL N-EXAM@20 method elsewhere-define: avg examScores 0.64 +/0 0.014
# OVERALL EXAM@20 method elsewhere-define: avg examScores 0.64 +/0 0.014
# OVERALL N-EXAM@20 method minor-channel: avg examScores 0.63 +/0 0.015
# OVERALL EXAM@20 method minor-channel: avg examScores 0.63 +/0 0.015
# OVERALL N-EXAM@20 method discover-universe: avg examScores 0.81 +/0 0.010
# OVERALL EXAM@20 method discover-universe: avg examScores 0.80 +/0 0.010
# OVERALL N-EXAM@20 method double-open: avg examScores 0.65 +/0 0.014
# OVERALL EXAM@20 method double-open: avg examScores 0.65 +/0 0.014
# OVERALL N-EXAM@20 method myth-emphasis: avg examScores 0.64 +/0 0.014
# OVERALL EXAM@20 method myth-emphasis: avg examScores 0.64 +/0 0.015
# OVERALL N-EXAM@20 method effectively-college: avg examScores 0.83 +/0 0.009
# OVERALL EXAM@20 method effectively-college: avg examScores 0.82 +/0 0.010
# OVERALL N-EXAM@20 method elite-democrat: avg examScores 0.62 +/0 0.015
# OVERALL EXAM@20 method elite-democrat: avg examScores 0.61 +/0 0.015
# OVERALL N-EXAM@20 method encounter-belong: avg examScores 0.76 +/0 0.012
# OVERALL EXAM@20 method encounter-belong: avg examScores 0.76 +/0 0.012
# OVERALL N-EXAM@20 method expansion-petrol: avg examScores 0.85 +/0 0.009
# OVERALL EXAM@20 method expansion-petrol: avg examScores 0.84 +/0 0.009
# OVERALL N-EXAM@20 method flow-cheap: avg examScores 0.44 +/0 0.015
# OVERALL EXAM@20 method flow-cheap: avg examScores 0.43 +/0 0.015
# OVERALL N-EXAM@20 method justice-tonight: avg examScores 0.57 +/0 0.015
# OVERALL EXAM@20 method justice-tonight: avg examScores 0.56 +/0 0.015
# OVERALL N-EXAM@20 method force-bring: avg examScores 0.61 +/0 0.017
# OVERALL EXAM@20 method force-bring: avg examScores 0.61 +/0 0.017
# OVERALL N-EXAM@20 method frame-permit: avg examScores 0.78 +/0 0.011
# OVERALL EXAM@20 method frame-permit: avg examScores 0.77 +/0 0.011
# OVERALL N-EXAM@20 method garlic-squeeze: avg examScores 0.67 +/0 0.014
# OVERALL EXAM@20 method garlic-squeeze: avg examScores 0.67 +/0 0.014
# OVERALL N-EXAM@20 method listen-responsible: avg examScores 0.65 +/0 0.014
# OVERALL EXAM@20 method listen-responsible: avg examScores 0.65 +/0 0.014
# OVERALL N-EXAM@20 method right-moon: avg examScores 0.41 +/0 0.015
# OVERALL EXAM@20 method right-moon: avg examScores 0.41 +/0 0.015
# OVERALL N-EXAM@20 method girl-cousin: avg examScores 0.60 +/0 0.015
# OVERALL EXAM@20 method girl-cousin: avg examScores 0.60 +/0 0.015
# OVERALL N-EXAM@20 method golf-species: avg examScores 0.83 +/0 0.010
# OVERALL EXAM@20 method golf-species: avg examScores 0.82 +/0 0.010
# OVERALL N-EXAM@20 method quite-specialist: avg examScores 0.83 +/0 0.010
# OVERALL EXAM@20 method quite-specialist: avg examScores 0.82 +/0 0.010
# OVERALL N-EXAM@20 method literally-championship: avg examScores 0.83 +/0 0.010
# OVERALL EXAM@20 method literally-championship: avg examScores 0.82 +/0 0.010
# OVERALL N-EXAM@20 method ground-gently: avg examScores 0.74 +/0 0.012
# OVERALL EXAM@20 method ground-gently: avg examScores 0.73 +/0 0.012
# OVERALL N-EXAM@20 method head-represent: avg examScores 0.74 +/0 0.014
# OVERALL EXAM@20 method head-represent: avg examScores 0.74 +/0 0.014
# OVERALL N-EXAM@20 method historic-adviser: avg examScores 0.70 +/0 0.013
# OVERALL EXAM@20 method historic-adviser: avg examScores 0.70 +/0 0.013
# OVERALL N-EXAM@20 method hunting-fishing: avg examScores 0.76 +/0 0.011
# OVERALL EXAM@20 method hunting-fishing: avg examScores 0.76 +/0 0.011
# OVERALL N-EXAM@20 method instructor-setting: avg examScores 0.77 +/0 0.012
# OVERALL EXAM@20 method instructor-setting: avg examScores 0.77 +/0 0.012
# OVERALL N-EXAM@20 method issue-shop: avg examScores 0.78 +/0 0.011
# OVERALL EXAM@20 method issue-shop: avg examScores 0.77 +/0 0.011
# OVERALL N-EXAM@20 method journey-lazy: avg examScores 0.59 +/0 0.015
# OVERALL EXAM@20 method journey-lazy: avg examScores 0.59 +/0 0.015
# OVERALL N-EXAM@20 method king-calculate: avg examScores 0.75 +/0 0.012
# OVERALL EXAM@20 method king-calculate: avg examScores 0.74 +/0 0.012
# OVERALL N-EXAM@20 method left-latin: avg examScores 0.67 +/0 0.014
# OVERALL EXAM@20 method left-latin: avg examScores 0.66 +/0 0.014
# OVERALL N-EXAM@20 method lesson-limited: avg examScores 0.75 +/0 0.012
# OVERALL EXAM@20 method lesson-limited: avg examScores 0.74 +/0 0.012
# OVERALL N-EXAM@20 method purchase-survivor: avg examScores 0.81 +/0 0.010
# OVERALL EXAM@20 method purchase-survivor: avg examScores 0.81 +/0 0.010
# OVERALL N-EXAM@20 method unless-happen: avg examScores 0.82 +/0 0.010
# OVERALL EXAM@20 method unless-happen: avg examScores 0.81 +/0 0.010
# OVERALL N-EXAM@20 method main-debt: avg examScores 0.62 +/0 0.015
# OVERALL EXAM@20 method main-debt: avg examScores 0.62 +/0 0.015
# OVERALL N-EXAM@20 method port-reform: avg examScores 0.63 +/0 0.015
# OVERALL EXAM@20 method port-reform: avg examScores 0.63 +/0 0.015
# OVERALL N-EXAM@20 method massive-hard: avg examScores 0.71 +/0 0.012
# OVERALL EXAM@20 method massive-hard: avg examScores 0.70 +/0 0.013
# OVERALL N-EXAM@20 method massive-luck: avg examScores 0.75 +/0 0.012
# OVERALL EXAM@20 method massive-luck: avg examScores 0.74 +/0 0.012
# OVERALL N-EXAM@20 method mental-refer: avg examScores 0.59 +/0 0.014
# OVERALL EXAM@20 method mental-refer: avg examScores 0.58 +/0 0.014
# OVERALL N-EXAM@20 method pilot-competitor: avg examScores 0.59 +/0 0.014
# OVERALL EXAM@20 method pilot-competitor: avg examScores 0.58 +/0 0.014
# OVERALL N-EXAM@20 method multiple-contact: avg examScores 0.78 +/0 0.011
# OVERALL EXAM@20 method multiple-contact: avg examScores 0.77 +/0 0.011
# OVERALL N-EXAM@20 method ongoing-stare: avg examScores 0.84 +/0 0.010
# OVERALL EXAM@20 method ongoing-stare: avg examScores 0.83 +/0 0.010
# OVERALL N-EXAM@20 method palm-long-term: avg examScores 0.86 +/0 0.009
# OVERALL EXAM@20 method palm-long-term: avg examScores 0.85 +/0 0.009
# OVERALL N-EXAM@20 method suspect-feed: avg examScores 0.86 +/0 0.009
# OVERALL EXAM@20 method suspect-feed: avg examScores 0.85 +/0 0.009
# OVERALL N-EXAM@20 method participate-factory: avg examScores 0.85 +/0 0.009
# OVERALL EXAM@20 method participate-factory: avg examScores 0.84 +/0 0.009
# OVERALL N-EXAM@20 method pepper-highlight: avg examScores 0.52 +/0 0.016
# OVERALL EXAM@20 method pepper-highlight: avg examScores 0.51 +/0 0.016
# OVERALL N-EXAM@20 method steady-merely: avg examScores 0.52 +/0 0.017
# OVERALL EXAM@20 method steady-merely: avg examScores 0.52 +/0 0.017
# OVERALL N-EXAM@20 method percentage-feeling: avg examScores 0.61 +/0 0.015
# OVERALL EXAM@20 method percentage-feeling: avg examScores 0.60 +/0 0.015
# OVERALL N-EXAM@20 method quality-courage: avg examScores 0.50 +/0 0.016
# OVERALL EXAM@20 method quality-courage: avg examScores 0.50 +/0 0.016
# OVERALL N-EXAM@20 method rank-friendly: avg examScores 0.74 +/0 0.012
# OVERALL EXAM@20 method rank-friendly: avg examScores 0.73 +/0 0.012
# OVERALL N-EXAM@20 method react-moral: avg examScores 0.80 +/0 0.010
# OVERALL EXAM@20 method react-moral: avg examScores 0.80 +/0 0.010
# OVERALL N-EXAM@20 method understanding-passenger: avg examScores 0.63 +/0 0.015
# OVERALL EXAM@20 method understanding-passenger: avg examScores 0.62 +/0 0.015
# OVERALL N-EXAM@20 method relation-loan: avg examScores 0.42 +/0 0.020
# OVERALL EXAM@20 method relation-loan: avg examScores 0.41 +/0 0.020
# OVERALL N-EXAM@20 method talent-evaluation: avg examScores 0.57 +/0 0.015
# OVERALL EXAM@20 method talent-evaluation: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method rose-canadian: avg examScores 0.77 +/0 0.011
# OVERALL EXAM@20 method rose-canadian: avg examScores 0.76 +/0 0.011
# OVERALL N-EXAM@20 method somewhere-holy: avg examScores 0.67 +/0 0.013
# OVERALL EXAM@20 method somewhere-holy: avg examScores 0.67 +/0 0.013
# OVERALL N-EXAM@20 method string-player: avg examScores 0.67 +/0 0.013
# OVERALL EXAM@20 method string-player: avg examScores 0.67 +/0 0.013
# OVERALL N-EXAM@20 method tram-begin: avg examScores 0.64 +/0 0.014
# OVERALL EXAM@20 method tram-begin: avg examScores 0.64 +/0 0.014
# OVERALL N-EXAM@20 method tremendous-whatever: avg examScores 0.86 +/0 0.008
# OVERALL EXAM@20 method tremendous-whatever: avg examScores 0.86 +/0 0.009
# OVERALL N-EXAM@20 method unusual-pain: avg examScores 0.72 +/0 0.012
# OVERALL EXAM@20 method unusual-pain: avg examScores 0.71 +/0 0.012
# OVERALL N-EXAM@20 method wisdom-trust: avg examScores 0.72 +/0 0.012
# OVERALL EXAM@20 method wisdom-trust: avg examScores 0.71 +/0 0.012
# OVERALL N-EXAM@20 method wooden-comedy: avg examScores 0.73 +/0 0.013
# OVERALL EXAM@20 method wooden-comedy: avg examScores 0.72 +/0 0.013
# OVERALL N-EXAM@20 method write-quarterback: avg examScores 0.78 +/0 0.011
# OVERALL EXAM@20 method write-quarterback: avg examScores 0.77 +/0 0.012
# ExamCover Leaderboard written to data/questions-rate--rubric-rag24-gen.jsonl.cover-1.tsv
# 2024-145979, overall ratio 0.9
# 2024-36935, overall ratio 0.9
# 2024-216592, overall ratio 1.0
# 2024-32912, overall ratio 1.0
# 2024-153051, overall ratio 0.9
# 2024-128784, overall ratio 1.0
# 2024-134815, overall ratio 1.0
# 2024-79081, overall ratio 1.0
# 2024-42497, overall ratio 0.6
# 2024-158743, overall ratio 1.0
# 2024-214630, overall ratio 1.0
# 2024-143869, overall ratio 1.0
# 2024-173513, overall ratio 1.0
# 2024-133137, overall ratio 0.9
# 2024-36155, overall ratio 0.9
# 2024-12875, overall ratio 1.0
# 2024-41477, overall ratio 1.0
# 2024-29941, overall ratio 0.7
# 2024-137315, overall ratio 1.0
# 2024-43037, overall ratio 1.0
# 2024-43983, overall ratio 0.9
# 2024-214126, overall ratio 0.9
# 2024-161461, overall ratio 0.9
# 2024-220140, overall ratio 0.9
# 2024-224279, overall ratio 1.0
# 2024-134629, overall ratio 1.0
# 2024-69711, overall ratio 0.9
# 2024-5957, overall ratio 0.9
# 2024-214096, overall ratio 1.0
# 2024-219624, overall ratio 1.0
# 2024-220058, overall ratio 1.0
# 2024-73340, overall ratio 0.9
# 2024-43972, overall ratio 0.9
# 2024-26688, overall ratio 1.0
# 2024-44060, overall ratio 0.9
# 2024-96359, overall ratio 1.0
# 2024-147909, overall ratio 1.0
# 2024-41918, overall ratio 1.0
# 2024-142395, overall ratio 1.0
# 2024-41610, overall ratio 1.0
# 2024-36857, overall ratio 1.0
# 2024-40863, overall ratio 1.0
# 2024-35284, overall ratio 1.0
# 2024-160253, overall ratio 1.0
# 2024-136156, overall ratio 1.0
# 2024-173795, overall ratio 1.0
# 2024-127653, overall ratio 0.9
# 2024-88894, overall ratio 0.8
# 2024-113646, overall ratio 1.0
# 2024-126056, overall ratio 1.0
# 2024-225026, overall ratio 1.0
# 2024-41960, overall ratio 1.0
# 2024-43905, overall ratio 0.9
# 2024-33359, overall ratio 1.0
# 2024-22886, overall ratio 0.8
# 2024-35269, overall ratio 1.0
# 2024-25032, overall ratio 1.0
# 2024-206384, overall ratio 1.0
# 2024-135747, overall ratio 1.0
# 2024-114095, overall ratio 1.0
# 2024-41198, overall ratio 1.0
# 2024-76908, overall ratio 0.9
# 2024-219626, overall ratio 0.9
# 2024-73918, overall ratio 0.9
# 2024-219661, overall ratio 1.0
# 2024-223914, overall ratio 1.0
# 2024-37173, overall ratio 1.0
# 2024-219824, overall ratio 1.0
# 2024-44059, overall ratio 1.0
# 2024-32796, overall ratio 1.0
# 2024-217279, overall ratio 1.0
# 2024-158261, overall ratio 0.9
# 2024-217241, overall ratio 1.0
# 2024-18963, overall ratio 0.9
# 2024-19025, overall ratio 1.0
# 2024-141577, overall ratio 1.0
# 2024-7058, overall ratio 1.0
# 2024-38461, overall ratio 1.0
# 2024-129925, overall ratio 0.9
# 2024-158677, overall ratio 0.9
# 2024-38379, overall ratio 1.0
# 2024-127288, overall ratio 0.9
# 2024-137182, overall ratio 1.0
# 2024-213469, overall ratio 0.8
# 2024-213817, overall ratio 0.9
# 2024-42781, overall ratio 0.8
# 2024-22900, overall ratio 1.0
# 2024-35620, overall ratio 1.0
# 2024-222481, overall ratio 1.0
# 2024-38611, overall ratio 0.9
# 2024-23680, overall ratio 0.8
# 2024-41849, overall ratio 0.9
# 2024-149459, overall ratio 1.0
# 2024-24226, overall ratio 0.9
# 2024-36302, overall ratio 1.0
# 2024-152259, overall ratio 1.0
# 2024-34582, overall ratio 0.8
# 2024-27366, overall ratio 1.0
# 2024-41796, overall ratio 1.0
# 2024-76647, overall ratio 1.0
# 2024-36338, overall ratio 1.0
# 2024-36672, overall ratio 1.0
# 2024-90454, overall ratio 1.0
# 2024-224926, overall ratio 0.7
# 2024-217812, overall ratio 1.0
# 2024-6778, overall ratio 1.0
# 2024-215952, overall ratio 1.0
# 2024-79154, overall ratio 1.0
# 2024-137667, overall ratio 0.9
# 2024-22410, overall ratio 1.0
# 2024-220307, overall ratio 0.8
# 2024-44329, overall ratio 1.0
# 2024-223358, overall ratio 1.0
# 2024-79113, overall ratio 1.0
# 2024-133810, overall ratio 1.0
# 2024-213978, overall ratio 0.8
# 2024-35320, overall ratio 1.0
# 2024-19947, overall ratio 1.0
# 2024-219698, overall ratio 0.9
# 2024-79129, overall ratio 1.0
# 2024-41465, overall ratio 1.0
# 2024-214052, overall ratio 1.0
# 2024-105741, overall ratio 1.0
# 2024-225247, overall ratio 0.8
# 2024-42376, overall ratio 1.0
# 2024-37531, overall ratio 0.8
# 2024-111506, overall ratio 1.0
# 2024-36131, overall ratio 0.9
# 2024-17909, overall ratio 0.9
# 2024-36186, overall ratio 1.0
# 2024-29182, overall ratio 1.0
# 2024-73921, overall ratio 1.0
# 2024-216231, overall ratio 1.0
# 2024-24022, overall ratio 1.0
# 2024-40724, overall ratio 1.0
# 2024-221429, overall ratio 1.0
# 2024-37596, overall ratio 1.0
# 2024-219631, overall ratio 1.0
# 2024-224710, overall ratio 1.0
# 2024-42645, overall ratio 1.0
# 2024-34521, overall ratio 1.0
# 2024-41334, overall ratio 0.9
# 2024-96063, overall ratio 1.0
# 2024-37470, overall ratio 1.0
# 2024-221278, overall ratio 0.9
# 2024-41464, overall ratio 1.0
# 2024-224621, overall ratio 1.0
# 2024-41563, overall ratio 1.0
# 2024-3824, overall ratio 0.9
# 2024-44754, overall ratio 1.0
# 2024-19454, overall ratio 1.0
# 2024-223499, overall ratio 1.0
# 2024-17605, overall ratio 1.0
# 2024-94706, overall ratio 1.0
# 2024-23862, overall ratio 0.9
# 2024-217496, overall ratio 1.0
# 2024-216957, overall ratio 1.0
# 2024-131116, overall ratio 1.0
# 2024-36741, overall ratio 1.0
# 2024-43684, overall ratio 1.0
# 2024-45185, overall ratio 1.0
# 2024-35834, overall ratio 0.9
# 2024-141280, overall ratio 0.9
# 2024-35506, overall ratio 0.8
# 2024-214257, overall ratio 0.9
# 2024-45474, overall ratio 1.0
# 2024-44024, overall ratio 1.0
# 2024-219271, overall ratio 1.0
# 2024-42163, overall ratio 1.0
# 2024-5992, overall ratio 1.0
# 2024-225389, overall ratio 1.0
# 2024-219385, overall ratio 0.7
# 2024-146077, overall ratio 1.0
# 2024-147273, overall ratio 1.0
# 2024-33466, overall ratio 1.0
# 2024-96485, overall ratio 1.0
# 2024-216598, overall ratio 1.0
# 2024-149261, overall ratio 1.0
# 2024-145295, overall ratio 1.0
# 2024-35227, overall ratio 0.9
# 2024-36355, overall ratio 1.0
# 2024-42556, overall ratio 1.0
# 2024-19448, overall ratio 1.0
# 2024-3653, overall ratio 1.0
# 2024-42195, overall ratio 1.0
# 2024-44048, overall ratio 0.9
# 2024-40831, overall ratio 1.0
# 2024-142330, overall ratio 1.0
# 2024-222465, overall ratio 0.9
# 2024-32534, overall ratio 0.9
# 2024-40868, overall ratio 1.0
# 2024-41077, overall ratio 1.0
# 2024-44544, overall ratio 0.8
# 2024-25195, overall ratio 1.0
# 2024-32856, overall ratio 1.0
# 2024-67021, overall ratio 1.0
# 2024-5675, overall ratio 0.7
# 2024-224063, overall ratio 0.9
# 2024-215090, overall ratio 0.8
# 2024-215256, overall ratio 0.8
# 2024-213855, overall ratio 1.0
# 2024-141993, overall ratio 1.0
# 2024-126414, overall ratio 1.0
# 2024-221836, overall ratio 0.9
# 2024-220794, overall ratio 1.0
# 2024-215044, overall ratio 0.7
# 2024-152817, overall ratio 0.9
# 2024-5809, overall ratio 1.0
# 2024-224960, overall ratio 0.9
# 2024-138052, overall ratio 1.0
# 2024-109837, overall ratio 1.0
# 2024-142125, overall ratio 1.0
# 2024-127349, overall ratio 1.0
# 2024-224701, overall ratio 0.9
# 2024-126326, overall ratio 1.0
# 2024-224013, overall ratio 0.9
# 2024-42464, overall ratio 0.8
# 2024-34595, overall ratio 1.0
# 2024-213491, overall ratio 1.0
# 2024-37566, overall ratio 1.0
# 2024-214744, overall ratio 0.8
# 2024-34710, overall ratio 0.8
# 2024-6587, overall ratio 1.0
# 2024-29222, overall ratio 1.0
# 2024-42738, overall ratio 1.0
# 2024-77150, overall ratio 0.9
# 2024-128311, overall ratio 1.0
# 2024-22919, overall ratio 1.0
# 2024-225531, overall ratio 0.8
# 2024-221442, overall ratio 1.0
# 2024-213789, overall ratio 1.0
# 2024-223094, overall ratio 0.6
# 2024-146893, overall ratio 1.0
# 2024-38428, overall ratio 1.0
# 2024-29936, overall ratio 1.0
# 2024-44001, overall ratio 1.0
# 2024-225456, overall ratio 1.0
# 2024-220679, overall ratio 0.9
# 2024-77099, overall ratio 0.9
# 2024-41711, overall ratio 1.0
# 2024-44065, overall ratio 1.0
# 2024-224226, overall ratio 0.8
# 2024-160888, overall ratio 1.0
# 2024-7532, overall ratio 1.0
# 2024-213901, overall ratio 1.0
# 2024-224399, overall ratio 1.0
# 2024-224207, overall ratio 1.0
# 2024-40996, overall ratio 1.0
# 2024-219896, overall ratio 0.9
# 2024-225150, overall ratio 1.0
# 2024-153070, overall ratio 1.0
# 2024-215094, overall ratio 1.0
# 2024-214333, overall ratio 1.0
# 2024-34583, overall ratio 1.0
# 2024-224339, overall ratio 1.0
# 2024-223829, overall ratio 0.9
# 2024-223855, overall ratio 1.0
# 2024-221022, overall ratio 1.0
# 2024-223382, overall ratio 0.7
# 2024-66937, overall ratio 1.0
# 2024-25003, overall ratio 1.0
# 2024-218590, overall ratio 1.0
# 2024-142084, overall ratio 1.0
# 2024-38986, overall ratio 0.9
# 2024-221364, overall ratio 0.9
# 2024-35596, overall ratio 1.0
# 2024-44005, overall ratio 1.0
# 2024-111331, overall ratio 0.9
# 2024-32502, overall ratio 1.0
# 2024-217582, overall ratio 1.0
# 2024-225223, overall ratio 1.0
# 2024-215833, overall ratio 0.7
# 2024-28144, overall ratio 0.8
# 2024-41576, overall ratio 0.8
# 2024-35485, overall ratio 0.6
# 2024-190455, overall ratio 0.9
# 2024-129062, overall ratio 1.0
# 2024-33513, overall ratio 1.0
# 2024-32817, overall ratio 1.0
# 2024-214483, overall ratio 1.0
# 2024-223345, overall ratio 0.9
# 2024-217488, overall ratio 1.0
# 2024-214467, overall ratio 1.0
# 2024-113215, overall ratio 0.9
# 2024-134964, overall ratio 1.0
# 2024-19562, overall ratio 1.0
# 2024-219563, overall ratio 0.9
# 2024-22172, overall ratio 1.0
# 2024-34927, overall ratio 1.0
# 2024-141453, overall ratio 0.9
# 2024-45494, overall ratio 1.0
# 2024-217827, overall ratio 1.0
# 2024-66915, overall ratio 1.0
# 2024-147917, overall ratio 0.9
# 2024-121840, overall ratio 0.8
# 2024-222696, overall ratio 0.9
# 2024-58819, overall ratio 0.7
# 2024-42014, overall ratio 1.0
# 2024-6862, overall ratio 1.0
# 2024-127266, overall ratio 0.8
# 2024-21669, overall ratio 0.9
# OVERALL N-EXAM@20 method _overall_: avg examScores 1.00 +/0 0.000
# OVERALL EXAM@20 method _overall_: avg examScores 0.95 +/0 0.005
# OVERALL N-EXAM@20 method according-useful: avg examScores 0.71 +/0 0.013
# OVERALL EXAM@20 method according-useful: avg examScores 0.68 +/0 0.013
# OVERALL N-EXAM@20 method account-born: avg examScores 0.42 +/0 0.016
# OVERALL EXAM@20 method account-born: avg examScores 0.41 +/0 0.016
# OVERALL N-EXAM@20 method tiny-e-mail: avg examScores 0.43 +/0 0.016
# OVERALL EXAM@20 method tiny-e-mail: avg examScores 0.41 +/0 0.016
# OVERALL N-EXAM@20 method activity-financial: avg examScores 0.63 +/0 0.015
# OVERALL EXAM@20 method activity-financial: avg examScores 0.61 +/0 0.015
# OVERALL N-EXAM@20 method agreement-helpful: avg examScores 0.53 +/0 0.016
# OVERALL EXAM@20 method agreement-helpful: avg examScores 0.52 +/0 0.016
# OVERALL N-EXAM@20 method assume-trip: avg examScores 0.52 +/0 0.015
# OVERALL EXAM@20 method assume-trip: avg examScores 0.50 +/0 0.015
# OVERALL N-EXAM@20 method product-lover: avg examScores 0.53 +/0 0.015
# OVERALL EXAM@20 method product-lover: avg examScores 0.51 +/0 0.016
# OVERALL N-EXAM@20 method violate-train: avg examScores 0.52 +/0 0.015
# OVERALL EXAM@20 method violate-train: avg examScores 0.50 +/0 0.015
# OVERALL N-EXAM@20 method basis-veteran: avg examScores 0.46 +/0 0.015
# OVERALL EXAM@20 method basis-veteran: avg examScores 0.45 +/0 0.015
# OVERALL N-EXAM@20 method gently-tennis: avg examScores 0.46 +/0 0.016
# OVERALL EXAM@20 method gently-tennis: avg examScores 0.45 +/0 0.016
# OVERALL N-EXAM@20 method shadow-remember: avg examScores 0.46 +/0 0.016
# OVERALL EXAM@20 method shadow-remember: avg examScores 0.45 +/0 0.016
# OVERALL N-EXAM@20 method battery-frequently: avg examScores 0.59 +/0 0.015
# OVERALL EXAM@20 method battery-frequently: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method beginning-french: avg examScores 0.31 +/0 0.016
# OVERALL EXAM@20 method beginning-french: avg examScores 0.30 +/0 0.016
# OVERALL N-EXAM@20 method cooking-every: avg examScores 0.38 +/0 0.017
# OVERALL EXAM@20 method cooking-every: avg examScores 0.37 +/0 0.017
# OVERALL N-EXAM@20 method current-scream: avg examScores 0.34 +/0 0.016
# OVERALL EXAM@20 method current-scream: avg examScores 0.33 +/0 0.016
# OVERALL N-EXAM@20 method elect-fifth: avg examScores 0.30 +/0 0.016
# OVERALL EXAM@20 method elect-fifth: avg examScores 0.29 +/0 0.016
# OVERALL N-EXAM@20 method honest-darkness: avg examScores 0.38 +/0 0.017
# OVERALL EXAM@20 method honest-darkness: avg examScores 0.37 +/0 0.017
# OVERALL N-EXAM@20 method length-very: avg examScores 0.34 +/0 0.016
# OVERALL EXAM@20 method length-very: avg examScores 0.33 +/0 0.016
# OVERALL N-EXAM@20 method space-traffic: avg examScores 0.42 +/0 0.018
# OVERALL EXAM@20 method space-traffic: avg examScores 0.41 +/0 0.017
# OVERALL N-EXAM@20 method would-regime: avg examScores 0.37 +/0 0.017
# OVERALL EXAM@20 method would-regime: avg examScores 0.36 +/0 0.017
# OVERALL N-EXAM@20 method business-square: avg examScores 0.54 +/0 0.016
# OVERALL EXAM@20 method business-square: avg examScores 0.52 +/0 0.016
# OVERALL N-EXAM@20 method press-wipe: avg examScores 0.54 +/0 0.016
# OVERALL EXAM@20 method press-wipe: avg examScores 0.52 +/0 0.016
# OVERALL N-EXAM@20 method capacity-indian: avg examScores 0.56 +/0 0.016
# OVERALL EXAM@20 method capacity-indian: avg examScores 0.54 +/0 0.016
# OVERALL N-EXAM@20 method climb-housing: avg examScores 0.69 +/0 0.013
# OVERALL EXAM@20 method climb-housing: avg examScores 0.66 +/0 0.014
# OVERALL N-EXAM@20 method coat-sequence: avg examScores 0.69 +/0 0.014
# OVERALL EXAM@20 method coat-sequence: avg examScores 0.67 +/0 0.014
# OVERALL N-EXAM@20 method competition-tell: avg examScores 0.31 +/0 0.016
# OVERALL EXAM@20 method competition-tell: avg examScores 0.30 +/0 0.016
# OVERALL N-EXAM@20 method computer-resource: avg examScores 0.59 +/0 0.015
# OVERALL EXAM@20 method computer-resource: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method concern-read: avg examScores 0.63 +/0 0.015
# OVERALL EXAM@20 method concern-read: avg examScores 0.61 +/0 0.015
# OVERALL N-EXAM@20 method crime-road: avg examScores 0.70 +/0 0.013
# OVERALL EXAM@20 method crime-road: avg examScores 0.67 +/0 0.013
# OVERALL N-EXAM@20 method develop-space: avg examScores 0.38 +/0 0.016
# OVERALL EXAM@20 method develop-space: avg examScores 0.37 +/0 0.016
# OVERALL N-EXAM@20 method proof-hunting: avg examScores 0.38 +/0 0.016
# OVERALL EXAM@20 method proof-hunting: avg examScores 0.37 +/0 0.016
# OVERALL N-EXAM@20 method differ-able: avg examScores 0.41 +/0 0.017
# OVERALL EXAM@20 method differ-able: avg examScores 0.40 +/0 0.017
# OVERALL N-EXAM@20 method elsewhere-define: avg examScores 0.48 +/0 0.017
# OVERALL EXAM@20 method elsewhere-define: avg examScores 0.46 +/0 0.017
# OVERALL N-EXAM@20 method minor-channel: avg examScores 0.42 +/0 0.017
# OVERALL EXAM@20 method minor-channel: avg examScores 0.41 +/0 0.017
# OVERALL N-EXAM@20 method discover-universe: avg examScores 0.67 +/0 0.014
# OVERALL EXAM@20 method discover-universe: avg examScores 0.64 +/0 0.014
# OVERALL N-EXAM@20 method double-open: avg examScores 0.43 +/0 0.016
# OVERALL EXAM@20 method double-open: avg examScores 0.42 +/0 0.016
# OVERALL N-EXAM@20 method myth-emphasis: avg examScores 0.43 +/0 0.017
# OVERALL EXAM@20 method myth-emphasis: avg examScores 0.41 +/0 0.017
# OVERALL N-EXAM@20 method effectively-college: avg examScores 0.69 +/0 0.014
# OVERALL EXAM@20 method effectively-college: avg examScores 0.66 +/0 0.014
# OVERALL N-EXAM@20 method elite-democrat: avg examScores 0.47 +/0 0.017
# OVERALL EXAM@20 method elite-democrat: avg examScores 0.45 +/0 0.017
# OVERALL N-EXAM@20 method encounter-belong: avg examScores 0.57 +/0 0.015
# OVERALL EXAM@20 method encounter-belong: avg examScores 0.55 +/0 0.015
# OVERALL N-EXAM@20 method expansion-petrol: avg examScores 0.70 +/0 0.014
# OVERALL EXAM@20 method expansion-petrol: avg examScores 0.67 +/0 0.014
# OVERALL N-EXAM@20 method flow-cheap: avg examScores 0.24 +/0 0.013
# OVERALL EXAM@20 method flow-cheap: avg examScores 0.24 +/0 0.013
# OVERALL N-EXAM@20 method justice-tonight: avg examScores 0.35 +/0 0.015
# OVERALL EXAM@20 method justice-tonight: avg examScores 0.34 +/0 0.015
# OVERALL N-EXAM@20 method force-bring: avg examScores 0.48 +/0 0.019
# OVERALL EXAM@20 method force-bring: avg examScores 0.46 +/0 0.019
# OVERALL N-EXAM@20 method frame-permit: avg examScores 0.60 +/0 0.015
# OVERALL EXAM@20 method frame-permit: avg examScores 0.58 +/0 0.015
# OVERALL N-EXAM@20 method garlic-squeeze: avg examScores 0.44 +/0 0.016
# OVERALL EXAM@20 method garlic-squeeze: avg examScores 0.43 +/0 0.016
# OVERALL N-EXAM@20 method listen-responsible: avg examScores 0.44 +/0 0.016
# OVERALL EXAM@20 method listen-responsible: avg examScores 0.42 +/0 0.016
# OVERALL N-EXAM@20 method right-moon: avg examScores 0.17 +/0 0.012
# OVERALL EXAM@20 method right-moon: avg examScores 0.17 +/0 0.011
# OVERALL N-EXAM@20 method girl-cousin: avg examScores 0.38 +/0 0.016
# OVERALL EXAM@20 method girl-cousin: avg examScores 0.37 +/0 0.016
# OVERALL N-EXAM@20 method golf-species: avg examScores 0.69 +/0 0.014
# OVERALL EXAM@20 method golf-species: avg examScores 0.66 +/0 0.014
# OVERALL N-EXAM@20 method quite-specialist: avg examScores 0.68 +/0 0.014
# OVERALL EXAM@20 method quite-specialist: avg examScores 0.66 +/0 0.014
# OVERALL N-EXAM@20 method literally-championship: avg examScores 0.68 +/0 0.014
# OVERALL EXAM@20 method literally-championship: avg examScores 0.66 +/0 0.014
# OVERALL N-EXAM@20 method ground-gently: avg examScores 0.54 +/0 0.015
# OVERALL EXAM@20 method ground-gently: avg examScores 0.52 +/0 0.015
# OVERALL N-EXAM@20 method head-represent: avg examScores 0.57 +/0 0.016
# OVERALL EXAM@20 method head-represent: avg examScores 0.55 +/0 0.016
# OVERALL N-EXAM@20 method historic-adviser: avg examScores 0.50 +/0 0.016
# OVERALL EXAM@20 method historic-adviser: avg examScores 0.48 +/0 0.016
# OVERALL N-EXAM@20 method hunting-fishing: avg examScores 0.59 +/0 0.015
# OVERALL EXAM@20 method hunting-fishing: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method instructor-setting: avg examScores 0.60 +/0 0.015
# OVERALL EXAM@20 method instructor-setting: avg examScores 0.58 +/0 0.015
# OVERALL N-EXAM@20 method issue-shop: avg examScores 0.60 +/0 0.014
# OVERALL EXAM@20 method issue-shop: avg examScores 0.58 +/0 0.014
# OVERALL N-EXAM@20 method journey-lazy: avg examScores 0.39 +/0 0.017
# OVERALL EXAM@20 method journey-lazy: avg examScores 0.37 +/0 0.016
# OVERALL N-EXAM@20 method king-calculate: avg examScores 0.59 +/0 0.015
# OVERALL EXAM@20 method king-calculate: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method left-latin: avg examScores 0.52 +/0 0.016
# OVERALL EXAM@20 method left-latin: avg examScores 0.50 +/0 0.016
# OVERALL N-EXAM@20 method lesson-limited: avg examScores 0.60 +/0 0.015
# OVERALL EXAM@20 method lesson-limited: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method purchase-survivor: avg examScores 0.66 +/0 0.013
# OVERALL EXAM@20 method purchase-survivor: avg examScores 0.64 +/0 0.014
# OVERALL N-EXAM@20 method unless-happen: avg examScores 0.68 +/0 0.014
# OVERALL EXAM@20 method unless-happen: avg examScores 0.65 +/0 0.014
# OVERALL N-EXAM@20 method main-debt: avg examScores 0.45 +/0 0.018
# OVERALL EXAM@20 method main-debt: avg examScores 0.44 +/0 0.018
# OVERALL N-EXAM@20 method port-reform: avg examScores 0.47 +/0 0.017
# OVERALL EXAM@20 method port-reform: avg examScores 0.45 +/0 0.017
# OVERALL N-EXAM@20 method massive-hard: avg examScores 0.55 +/0 0.015
# OVERALL EXAM@20 method massive-hard: avg examScores 0.53 +/0 0.016
# OVERALL N-EXAM@20 method massive-luck: avg examScores 0.59 +/0 0.016
# OVERALL EXAM@20 method massive-luck: avg examScores 0.57 +/0 0.016
# OVERALL N-EXAM@20 method mental-refer: avg examScores 0.30 +/0 0.015
# OVERALL EXAM@20 method mental-refer: avg examScores 0.29 +/0 0.014
# OVERALL N-EXAM@20 method pilot-competitor: avg examScores 0.30 +/0 0.015
# OVERALL EXAM@20 method pilot-competitor: avg examScores 0.29 +/0 0.014
# OVERALL N-EXAM@20 method multiple-contact: avg examScores 0.61 +/0 0.014
# OVERALL EXAM@20 method multiple-contact: avg examScores 0.59 +/0 0.014
# OVERALL N-EXAM@20 method ongoing-stare: avg examScores 0.69 +/0 0.013
# OVERALL EXAM@20 method ongoing-stare: avg examScores 0.67 +/0 0.014
# OVERALL N-EXAM@20 method palm-long-term: avg examScores 0.71 +/0 0.012
# OVERALL EXAM@20 method palm-long-term: avg examScores 0.68 +/0 0.013
# OVERALL N-EXAM@20 method suspect-feed: avg examScores 0.71 +/0 0.012
# OVERALL EXAM@20 method suspect-feed: avg examScores 0.68 +/0 0.013
# OVERALL N-EXAM@20 method participate-factory: avg examScores 0.71 +/0 0.013
# OVERALL EXAM@20 method participate-factory: avg examScores 0.68 +/0 0.013
# OVERALL N-EXAM@20 method pepper-highlight: avg examScores 0.31 +/0 0.017
# OVERALL EXAM@20 method pepper-highlight: avg examScores 0.30 +/0 0.017
# OVERALL N-EXAM@20 method steady-merely: avg examScores 0.32 +/0 0.017
# OVERALL EXAM@20 method steady-merely: avg examScores 0.31 +/0 0.017
# OVERALL N-EXAM@20 method percentage-feeling: avg examScores 0.41 +/0 0.016
# OVERALL EXAM@20 method percentage-feeling: avg examScores 0.39 +/0 0.016
# OVERALL N-EXAM@20 method quality-courage: avg examScores 0.30 +/0 0.016
# OVERALL EXAM@20 method quality-courage: avg examScores 0.30 +/0 0.016
# OVERALL N-EXAM@20 method rank-friendly: avg examScores 0.57 +/0 0.015
# OVERALL EXAM@20 method rank-friendly: avg examScores 0.55 +/0 0.015
# OVERALL N-EXAM@20 method react-moral: avg examScores 0.64 +/0 0.014
# OVERALL EXAM@20 method react-moral: avg examScores 0.62 +/0 0.014
# OVERALL N-EXAM@20 method understanding-passenger: avg examScores 0.41 +/0 0.017
# OVERALL EXAM@20 method understanding-passenger: avg examScores 0.40 +/0 0.017
# OVERALL N-EXAM@20 method relation-loan: avg examScores 0.23 +/0 0.017
# OVERALL EXAM@20 method relation-loan: avg examScores 0.22 +/0 0.017
# OVERALL N-EXAM@20 method talent-evaluation: avg examScores 0.32 +/0 0.014
# OVERALL EXAM@20 method talent-evaluation: avg examScores 0.31 +/0 0.014
# OVERALL N-EXAM@20 method rose-canadian: avg examScores 0.59 +/0 0.015
# OVERALL EXAM@20 method rose-canadian: avg examScores 0.57 +/0 0.015
# OVERALL N-EXAM@20 method somewhere-holy: avg examScores 0.52 +/0 0.016
# OVERALL EXAM@20 method somewhere-holy: avg examScores 0.50 +/0 0.016
# OVERALL N-EXAM@20 method string-player: avg examScores 0.52 +/0 0.016
# OVERALL EXAM@20 method string-player: avg examScores 0.50 +/0 0.016
# OVERALL N-EXAM@20 method tram-begin: avg examScores 0.37 +/0 0.017
# OVERALL EXAM@20 method tram-begin: avg examScores 0.35 +/0 0.016
# OVERALL N-EXAM@20 method tremendous-whatever: avg examScores 0.72 +/0 0.013
# OVERALL EXAM@20 method tremendous-whatever: avg examScores 0.69 +/0 0.013
# OVERALL N-EXAM@20 method unusual-pain: avg examScores 0.56 +/0 0.015
# OVERALL EXAM@20 method unusual-pain: avg examScores 0.54 +/0 0.016
# OVERALL N-EXAM@20 method wisdom-trust: avg examScores 0.54 +/0 0.015
# OVERALL EXAM@20 method wisdom-trust: avg examScores 0.52 +/0 0.016
# OVERALL N-EXAM@20 method wooden-comedy: avg examScores 0.53 +/0 0.016
# OVERALL EXAM@20 method wooden-comedy: avg examScores 0.51 +/0 0.016
# OVERALL N-EXAM@20 method write-quarterback: avg examScores 0.62 +/0 0.015
# OVERALL EXAM@20 method write-quarterback: avg examScores 0.60 +/0 0.016
# ExamCover Leaderboard written to data/questions-rate--rubric-rag24-gen.jsonl.cover-4.tsv
# 2024-145979, overall ratio 0.8
# 2024-36935, overall ratio 0.5
# 2024-216592, overall ratio 0.8
# 2024-32912, overall ratio 0.2
# 2024-153051, overall ratio 0.9
# 2024-128784, overall ratio 0.7
# 2024-134815, overall ratio 0.5
# 2024-79081, overall ratio 0.7
# 2024-42497, overall ratio 0.3
# 2024-158743, overall ratio 0.2
# 2024-214630, overall ratio 0.9
# 2024-143869, overall ratio 0.9
# 2024-173513, overall ratio 1.0
# 2024-133137, overall ratio 0.8
# 2024-36155, overall ratio 0.8
# 2024-12875, overall ratio 0.7
# 2024-41477, overall ratio 0.3
# 2024-29941, overall ratio 0.2
# 2024-137315, overall ratio 0.9
# 2024-43037, overall ratio 0.8
# 2024-43983, overall ratio 0.9
# 2024-214126, overall ratio 0.3
# 2024-161461, overall ratio 0.6
# 2024-220140, overall ratio 0.6
# 2024-224279, overall ratio 0.9
# 2024-134629, overall ratio 0.8
# 2024-69711, overall ratio 0.5
# 2024-5957, overall ratio 0.3
# 2024-214096, overall ratio 0.1
# 2024-219624, overall ratio 0.2
# 2024-220058, overall ratio 0.2
# 2024-73340, overall ratio 0.7
# 2024-43972, overall ratio 0.8
# 2024-26688, overall ratio 0.4
# 2024-44060, overall ratio 0.6
# 2024-96359, overall ratio 0.5
# 2024-147909, overall ratio 0.5
# 2024-41918, overall ratio 0.7
# 2024-142395, overall ratio 0.8
# 2024-41610, overall ratio 0.9
# 2024-36857, overall ratio 0.2
# 2024-40863, overall ratio 0.8
# 2024-35284, overall ratio 1.0
# 2024-160253, overall ratio 0.8
# 2024-136156, overall ratio 0.8
# 2024-173795, overall ratio 0.4
# 2024-127653, overall ratio 0.6
# 2024-88894, overall ratio 0.4
# 2024-113646, overall ratio 0.2
# 2024-126056, overall ratio 0.3
# 2024-225026, overall ratio 0.7
# 2024-41960, overall ratio 0.6
# 2024-43905, overall ratio 0.5
# 2024-33359, overall ratio 0.7
# 2024-22886, overall ratio 0.3
# 2024-35269, overall ratio 0.7
# 2024-25032, overall ratio 0.3
# 2024-206384, overall ratio 0.5
# 2024-135747, overall ratio 0.8
# 2024-114095, overall ratio 0.6
# 2024-41198, overall ratio 0.7
# 2024-76908, overall ratio 0.1
# 2024-219626, overall ratio 0.1
# 2024-73918, overall ratio 0.1
# 2024-219661, overall ratio 0.7
# 2024-223914, overall ratio 0.6
# 2024-37173, overall ratio 0.6
# 2024-219824, overall ratio 0.5
# 2024-44059, overall ratio 0.0
# 2024-32796, overall ratio 0.5
# 2024-217279, overall ratio 0.3
# 2024-158261, overall ratio 0.7
# 2024-217241, overall ratio 0.8
# 2024-18963, overall ratio 0.5
# 2024-19025, overall ratio 0.7
# 2024-141577, overall ratio 0.4
# 2024-7058, overall ratio 0.8
# 2024-38461, overall ratio 0.6
# 2024-129925, overall ratio 0.7
# 2024-158677, overall ratio 0.3
# 2024-38379, overall ratio 0.7
# 2024-127288, overall ratio 0.2
# 2024-137182, overall ratio 0.5
# 2024-213469, overall ratio 0.1
# 2024-213817, overall ratio 0.3
# 2024-42781, overall ratio 0.6
# 2024-22900, overall ratio 0.8
# 2024-35620, overall ratio 0.8
# 2024-222481, overall ratio 0.3
# 2024-38611, overall ratio 0.8
# 2024-23680, overall ratio 0.4
# 2024-41849, overall ratio 0.1
# 2024-149459, overall ratio 0.2
# 2024-24226, overall ratio 0.3
# 2024-36302, overall ratio 0.5454545454545454
# 2024-152259, overall ratio 0.6
# 2024-34582, overall ratio 0.2
# 2024-27366, overall ratio 0.7
# 2024-41796, overall ratio 0.8
# 2024-76647, overall ratio 0.1
# 2024-36338, overall ratio 0.5
# 2024-36672, overall ratio 0.6
# 2024-90454, overall ratio 0.8
# 2024-224926, overall ratio 0.1
# 2024-217812, overall ratio 0.2
# ...
# OVERALL EXAM-qrels method rank-friendly: avg examScores 0.36 +/0 0.006
# OVERALL EXAM-qrels method react-moral: avg examScores 0.44 +/0 0.008
# OVERALL EXAM-qrels method relation-loan: avg examScores 0.21 +/0 0.011
# OVERALL EXAM-qrels method right-moon: avg examScores 0.28 +/0 0.011
# OVERALL EXAM-qrels method rose-canadian: avg examScores 0.35 +/0 0.005
# OVERALL EXAM-qrels method shadow-remember: avg examScores 0.21 +/0 0.004
# OVERALL EXAM-qrels method somewhere-holy: avg examScores 0.20 +/0 0.007
# OVERALL EXAM-qrels method space-traffic: avg examScores 0.23 +/0 0.010
# OVERALL EXAM-qrels method steady-merely: avg examScores 0.13 +/0 0.007
# OVERALL EXAM-qrels method string-player: avg examScores 0.20 +/0 0.007
# OVERALL EXAM-qrels method suspect-feed: avg examScores 0.69 +/0 0.010
# OVERALL EXAM-qrels method talent-evaluation: avg examScores 0.38 +/0 0.010
# OVERALL EXAM-qrels method tiny-e-mail: avg examScores 0.27 +/0 0.009
# OVERALL EXAM-qrels method tram-begin: avg examScores 0.42 +/0 0.011
# OVERALL EXAM-qrels method tremendous-whatever: avg examScores 0.62 +/0 0.009
# OVERALL EXAM-qrels method understanding-passenger: avg examScores 0.24 +/0 0.010
# OVERALL EXAM-qrels method unless-happen: avg examScores 0.58 +/0 0.011
# OVERALL EXAM-qrels method unusual-pain: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method violate-train: avg examScores 0.38 +/0 0.010
# OVERALL EXAM-qrels method wisdom-trust: avg examScores 0.23 +/0 0.005
# OVERALL EXAM-qrels method wooden-comedy: avg examScores 0.37 +/0 0.010
# OVERALL EXAM-qrels method would-regime: avg examScores 0.16 +/0 0.006
# OVERALL EXAM-qrels method write-quarterback: avg examScores 0.27 +/0 0.005
# ExamCover Leaderboard written to data/questions-rate--rubric-rag24-gen.jsonl.qrels-1.tsv
# Running trec_eval command:
# for f in *.run; do  res=`trec_eval -n -c -q -m P.20  -l 4  /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl.qrel $f`; echo "$f $res"; done
# in directory: data/questions-rate--rubric-rag24-gen.jsonl-runs
# OVERALL EXAM-qrels method _overall_: avg examScores 0.00 +/0 0.000
# OVERALL EXAM-qrels method according-useful: avg examScores 0.45 +/0 0.010
# OVERALL EXAM-qrels method account-born: avg examScores 0.15 +/0 0.006
# OVERALL EXAM-qrels method activity-financial: avg examScores 0.28 +/0 0.007
# OVERALL EXAM-qrels method agreement-helpful: avg examScores 0.21 +/0 0.008
# OVERALL EXAM-qrels method assume-trip: avg examScores 0.25 +/0 0.010
# OVERALL EXAM-qrels method basis-veteran: avg examScores 0.16 +/0 0.005
# OVERALL EXAM-qrels method battery-frequently: avg examScores 0.28 +/0 0.008
# OVERALL EXAM-qrels method beginning-french: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method business-square: avg examScores 0.17 +/0 0.006
# OVERALL EXAM-qrels method capacity-indian: avg examScores 0.24 +/0 0.007
# OVERALL EXAM-qrels method climb-housing: avg examScores 0.44 +/0 0.010
# OVERALL EXAM-qrels method coat-sequence: avg examScores 0.34 +/0 0.007
# OVERALL EXAM-qrels method competition-tell: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method computer-resource: avg examScores 0.25 +/0 0.007
# OVERALL EXAM-qrels method concern-read: avg examScores 0.23 +/0 0.006
# OVERALL EXAM-qrels method cooking-every: avg examScores 0.11 +/0 0.006
# OVERALL EXAM-qrels method crime-road: avg examScores 0.44 +/0 0.010
# OVERALL EXAM-qrels method current-scream: avg examScores 0.08 +/0 0.005
# OVERALL EXAM-qrels method develop-space: avg examScores 0.10 +/0 0.004
# OVERALL EXAM-qrels method differ-able: avg examScores 0.18 +/0 0.009
# OVERALL EXAM-qrels method discover-universe: avg examScores 0.43 +/0 0.012
# OVERALL EXAM-qrels method double-open: avg examScores 0.17 +/0 0.007
# OVERALL EXAM-qrels method effectively-college: avg examScores 0.45 +/0 0.012
# OVERALL EXAM-qrels method elect-fifth: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method elite-democrat: avg examScores 0.13 +/0 0.005
# OVERALL EXAM-qrels method elsewhere-define: avg examScores 0.13 +/0 0.005
# OVERALL EXAM-qrels method encounter-belong: avg examScores 0.32 +/0 0.011
# OVERALL EXAM-qrels method expansion-petrol: avg examScores 0.49 +/0 0.012
# OVERALL EXAM-qrels method flow-cheap: avg examScores 0.09 +/0 0.004
# OVERALL EXAM-qrels method force-bring: avg examScores 0.12 +/0 0.007
# OVERALL EXAM-qrels method frame-permit: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method garlic-squeeze: avg examScores 0.13 +/0 0.004
# OVERALL EXAM-qrels method gently-tennis: avg examScores 0.16 +/0 0.005
# OVERALL EXAM-qrels method girl-cousin: avg examScores 0.10 +/0 0.005
# OVERALL EXAM-qrels method golf-species: avg examScores 0.44 +/0 0.012
# OVERALL EXAM-qrels method ground-gently: avg examScores 0.25 +/0 0.009
# OVERALL EXAM-qrels method head-represent: avg examScores 0.31 +/0 0.013
# OVERALL EXAM-qrels method historic-adviser: avg examScores 0.26 +/0 0.010
# OVERALL EXAM-qrels method honest-darkness: avg examScores 0.11 +/0 0.006
# OVERALL EXAM-qrels method hunting-fishing: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method instructor-setting: avg examScores 0.27 +/0 0.006
# OVERALL EXAM-qrels method issue-shop: avg examScores 0.28 +/0 0.006
# OVERALL EXAM-qrels method journey-lazy: avg examScores 0.12 +/0 0.006
# OVERALL EXAM-qrels method justice-tonight: avg examScores 0.19 +/0 0.008
# OVERALL EXAM-qrels method king-calculate: avg examScores 0.25 +/0 0.007
# OVERALL EXAM-qrels method left-latin: avg examScores 0.18 +/0 0.007
# OVERALL EXAM-qrels method length-very: avg examScores 0.09 +/0 0.005
# OVERALL EXAM-qrels method lesson-limited: avg examScores 0.24 +/0 0.007
# OVERALL EXAM-qrels method listen-responsible: avg examScores 0.12 +/0 0.004
# OVERALL EXAM-qrels method literally-championship: avg examScores 0.43 +/0 0.012
# OVERALL EXAM-qrels method main-debt: avg examScores 0.10 +/0 0.005
# OVERALL EXAM-qrels method massive-hard: avg examScores 0.18 +/0 0.005
# OVERALL EXAM-qrels method massive-luck: avg examScores 0.22 +/0 0.008
# OVERALL EXAM-qrels method mental-refer: avg examScores 0.28 +/0 0.016
# OVERALL EXAM-qrels method minor-channel: avg examScores 0.17 +/0 0.009
# OVERALL EXAM-qrels method multiple-contact: avg examScores 0.28 +/0 0.006
# OVERALL EXAM-qrels method myth-emphasis: avg examScores 0.16 +/0 0.008
# OVERALL EXAM-qrels method ongoing-stare: avg examScores 0.52 +/0 0.012
# OVERALL EXAM-qrels method palm-long-term: avg examScores 0.51 +/0 0.012
# OVERALL EXAM-qrels method participate-factory: avg examScores 0.44 +/0 0.010
# OVERALL EXAM-qrels method pepper-highlight: avg examScores 0.08 +/0 0.006
# OVERALL EXAM-qrels method percentage-feeling: avg examScores 0.11 +/0 0.005
# OVERALL EXAM-qrels method pilot-competitor: avg examScores 0.28 +/0 0.016
# OVERALL EXAM-qrels method port-reform: avg examScores 0.11 +/0 0.005
# OVERALL EXAM-qrels method press-wipe: avg examScores 0.17 +/0 0.006
# OVERALL EXAM-qrels method product-lover: avg examScores 0.24 +/0 0.009
# OVERALL EXAM-qrels method proof-hunting: avg examScores 0.09 +/0 0.004
# OVERALL EXAM-qrels method purchase-survivor: avg examScores 0.42 +/0 0.010
# OVERALL EXAM-qrels method quality-courage: avg examScores 0.05 +/0 0.003
# OVERALL EXAM-qrels method quite-specialist: avg examScores 0.42 +/0 0.012
# OVERALL EXAM-qrels method rank-friendly: avg examScores 0.27 +/0 0.007
# OVERALL EXAM-qrels method react-moral: avg examScores 0.33 +/0 0.008
# OVERALL EXAM-qrels method relation-loan: avg examScores 0.11 +/0 0.009
# OVERALL EXAM-qrels method right-moon: avg examScores 0.10 +/0 0.008
# OVERALL EXAM-qrels method rose-canadian: avg examScores 0.27 +/0 0.007
# OVERALL EXAM-qrels method shadow-remember: avg examScores 0.16 +/0 0.005
# OVERALL EXAM-qrels method somewhere-holy: avg examScores 0.16 +/0 0.007
# OVERALL EXAM-qrels method space-traffic: avg examScores 0.17 +/0 0.009
# OVERALL EXAM-qrels method steady-merely: avg examScores 0.09 +/0 0.005
# OVERALL EXAM-qrels method string-player: avg examScores 0.16 +/0 0.007
# OVERALL EXAM-qrels method suspect-feed: avg examScores 0.51 +/0 0.012
# OVERALL EXAM-qrels method talent-evaluation: avg examScores 0.16 +/0 0.009
# OVERALL EXAM-qrels method tiny-e-mail: avg examScores 0.16 +/0 0.007
# OVERALL EXAM-qrels method tram-begin: avg examScores 0.23 +/0 0.011
# OVERALL EXAM-qrels method tremendous-whatever: avg examScores 0.46 +/0 0.010
# OVERALL EXAM-qrels method understanding-passenger: avg examScores 0.17 +/0 0.009
# OVERALL EXAM-qrels method unless-happen: avg examScores 0.44 +/0 0.012
# OVERALL EXAM-qrels method unusual-pain: avg examScores 0.21 +/0 0.006
# OVERALL EXAM-qrels method violate-train: avg examScores 0.25 +/0 0.010
# OVERALL EXAM-qrels method wisdom-trust: avg examScores 0.17 +/0 0.005
# OVERALL EXAM-qrels method wooden-comedy: avg examScores 0.24 +/0 0.009
# OVERALL EXAM-qrels method would-regime: avg examScores 0.11 +/0 0.005
# OVERALL EXAM-qrels method write-quarterback: avg examScores 0.21 +/0 0.006
# ExamCover Leaderboard written to data/questions-rate--rubric-rag24-gen.jsonl.qrels-4.tsv
# Running trec_eval command:
# for f in *.run; do  res=`trec_eval -n -c -q -m P.20  -l 5  /home/dietz/trec-car/exampp/rubric-trec-rag/data/questions-rate--rubric-rag24-gen.jsonl.qrel $f`; echo "$f $res"; done
# in directory: data/questions-rate--rubric-rag24-gen.jsonl-runs
# OVERALL EXAM-qrels method _overall_: avg examScores 0.00 +/0 0.000
# OVERALL EXAM-qrels method according-useful: avg examScores 0.13 +/0 0.010
# OVERALL EXAM-qrels method account-born: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method activity-financial: avg examScores 0.09 +/0 0.007
# OVERALL EXAM-qrels method agreement-helpful: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method assume-trip: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method basis-veteran: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method battery-frequently: avg examScores 0.08 +/0 0.007
# OVERALL EXAM-qrels method beginning-french: avg examScores 0.01 +/0 0.001
# OVERALL EXAM-qrels method business-square: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method capacity-indian: avg examScores 0.06 +/0 0.006
# OVERALL EXAM-qrels method climb-housing: avg examScores 0.12 +/0 0.009
# OVERALL EXAM-qrels method coat-sequence: avg examScores 0.10 +/0 0.007
# OVERALL EXAM-qrels method competition-tell: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method computer-resource: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method concern-read: avg examScores 0.07 +/0 0.005
# OVERALL EXAM-qrels method cooking-every: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method crime-road: avg examScores 0.12 +/0 0.009
# OVERALL EXAM-qrels method current-scream: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method develop-space: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method differ-able: avg examScores 0.04 +/0 0.004
# OVERALL EXAM-qrels method discover-universe: avg examScores 0.12 +/0 0.010
# OVERALL EXAM-qrels method double-open: avg examScores 0.04 +/0 0.004
# OVERALL EXAM-qrels method effectively-college: avg examScores 0.12 +/0 0.010
# OVERALL EXAM-qrels method elect-fifth: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method elite-democrat: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method elsewhere-define: avg examScores 0.04 +/0 0.003
# OVERALL EXAM-qrels method encounter-belong: avg examScores 0.06 +/0 0.006
# OVERALL EXAM-qrels method expansion-petrol: avg examScores 0.12 +/0 0.009
# OVERALL EXAM-qrels method flow-cheap: avg examScores 0.01 +/0 0.002
# OVERALL EXAM-qrels method force-bring: avg examScores 0.03 +/0 0.004
# OVERALL EXAM-qrels method frame-permit: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method garlic-squeeze: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method gently-tennis: avg examScores 0.04 +/0 0.004
# OVERALL EXAM-qrels method girl-cousin: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method golf-species: avg examScores 0.12 +/0 0.010
# OVERALL EXAM-qrels method ground-gently: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method head-represent: avg examScores 0.07 +/0 0.007
# OVERALL EXAM-qrels method historic-adviser: avg examScores 0.06 +/0 0.006
# OVERALL EXAM-qrels method honest-darkness: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method hunting-fishing: avg examScores 0.08 +/0 0.006
# OVERALL EXAM-qrels method instructor-setting: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method issue-shop: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method journey-lazy: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method justice-tonight: avg examScores 0.03 +/0 0.004
# OVERALL EXAM-qrels method king-calculate: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method left-latin: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method length-very: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method lesson-limited: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method listen-responsible: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method literally-championship: avg examScores 0.12 +/0 0.010
# OVERALL EXAM-qrels method main-debt: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method massive-hard: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method massive-luck: avg examScores 0.06 +/0 0.006
# OVERALL EXAM-qrels method mental-refer: avg examScores 0.04 +/0 0.007
# OVERALL EXAM-qrels method minor-channel: avg examScores 0.04 +/0 0.004
# OVERALL EXAM-qrels method multiple-contact: avg examScores 0.07 +/0 0.006
# OVERALL EXAM-qrels method myth-emphasis: avg examScores 0.03 +/0 0.004
# OVERALL EXAM-qrels method ongoing-stare: avg examScores 0.14 +/0 0.011
# OVERALL EXAM-qrels method palm-long-term: avg examScores 0.13 +/0 0.010
# OVERALL EXAM-qrels method participate-factory: avg examScores 0.13 +/0 0.009
# OVERALL EXAM-qrels method pepper-highlight: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method percentage-feeling: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method pilot-competitor: avg examScores 0.04 +/0 0.007
# OVERALL EXAM-qrels method port-reform: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method press-wipe: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method product-lover: avg examScores 0.05 +/0 0.006
# OVERALL EXAM-qrels method proof-hunting: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method purchase-survivor: avg examScores 0.11 +/0 0.009
# OVERALL EXAM-qrels method quality-courage: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method quite-specialist: avg examScores 0.11 +/0 0.009
# OVERALL EXAM-qrels method rank-friendly: avg examScores 0.06 +/0 0.006
# OVERALL EXAM-qrels method react-moral: avg examScores 0.08 +/0 0.006
# OVERALL EXAM-qrels method relation-loan: avg examScores 0.03 +/0 0.004
# OVERALL EXAM-qrels method right-moon: avg examScores 0.01 +/0 0.002
# OVERALL EXAM-qrels method rose-canadian: avg examScores 0.07 +/0 0.005
# OVERALL EXAM-qrels method shadow-remember: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method somewhere-holy: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method space-traffic: avg examScores 0.04 +/0 0.004
# OVERALL EXAM-qrels method steady-merely: avg examScores 0.02 +/0 0.002
# OVERALL EXAM-qrels method string-player: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method suspect-feed: avg examScores 0.13 +/0 0.010
# OVERALL EXAM-qrels method talent-evaluation: avg examScores 0.02 +/0 0.003
# OVERALL EXAM-qrels method tiny-e-mail: avg examScores 0.03 +/0 0.004
# OVERALL EXAM-qrels method tram-begin: avg examScores 0.04 +/0 0.005
# OVERALL EXAM-qrels method tremendous-whatever: avg examScores 0.12 +/0 0.009
# OVERALL EXAM-qrels method understanding-passenger: avg examScores 0.04 +/0 0.004
# OVERALL EXAM-qrels method unless-happen: avg examScores 0.12 +/0 0.010
# OVERALL EXAM-qrels method unusual-pain: avg examScores 0.06 +/0 0.005
# OVERALL EXAM-qrels method violate-train: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method wisdom-trust: avg examScores 0.05 +/0 0.004
# OVERALL EXAM-qrels method wooden-comedy: avg examScores 0.05 +/0 0.005
# OVERALL EXAM-qrels method would-regime: avg examScores 0.03 +/0 0.003
# OVERALL EXAM-qrels method write-quarterback: avg examScores 0.07 +/0 0.005
# ExamCover Leaderboard written to data/questions-rate--rubric-rag24-gen.jsonl.qrels-5.tsv

# %%
# collect leaderboards from different RUBRIC measures

boards={"cover-1": cover_result1
    , "cover-4": cover_result4
    , "cover-5": cover_result5
    , "qrels-ndcg": qrel_result_ndcg
    , "qrels-1": qrel_result1
    , "qrels-4": qrel_result4
    , "qrels-5": qrel_result5
}

# %%
# Export system evaluation scores per system/query/measure

@dataclass
class RunMeasureTopicValue():
    run:str
    measure:str
    topic:str
    value:float

# function to run the export
def export_method_measure_topic_value_format(boards:Dict[str, ExamCoverEvals]):
    export_lines = list()
    for measure, cover_evals_dict in boards.items():
        for method, cover_evals in cover_evals_dict.items():
            lines = [RunMeasureTopicValue(run=cover_evals.method, measure=measure, topic=topic, value=v) 
                         for topic, v in cover_evals.examCoverPerQuery.items()
                         # if cover_evals.method != "_overall_"
                   ]
            export_lines.extend(lines)
    return export_lines

# perform export
lines = export_method_measure_topic_value_format(boards)
with open(export_file, "wt") as file:
    file.write("\n".join( [ f"{line.run}\t{line.measure}\t{line.topic}\t{line.value}" for line in lines]))
    file.flush()

# example output
lines[0:10000:300]
# Out:
# [RunMeasureTopicValue(run='_overall_', measure='cover-1', topic='2024-145979', value=1.0),
#  RunMeasureTopicValue(run='_overall_', measure='cover-1', topic='2024-21669', value=1.0),
#  RunMeasureTopicValue(run='according-useful', measure='cover-1', topic='2024-127266', value=0.9),
#  RunMeasureTopicValue(run='account-born', measure='cover-1', topic='2024-6862', value=0.5),
#  RunMeasureTopicValue(run='tiny-e-mail', measure='cover-1', topic='2024-42014', value=0.5),
#  RunMeasureTopicValue(run='activity-financial', measure='cover-1', topic='2024-58819', value=0.5),
#  RunMeasureTopicValue(run='agreement-helpful', measure='cover-1', topic='2024-222696', value=1.0),
#  RunMeasureTopicValue(run='assume-trip', measure='cover-1', topic='2024-121840', value=0.4),
#  RunMeasureTopicValue(run='product-lover', measure='cover-1', topic='2024-147917', value=0.3),
#  RunMeasureTopicValue(run='violate-train', measure='cover-1', topic='2024-66915', value=0.7),
#  RunMeasureTopicValue(run='basis-veteran', measure='cover-1', topic='2024-217827', value=0.3),
#  RunMeasureTopicValue(run='gently-tennis', measure='cover-1', topic='2024-45494', value=1.0),
#  RunMeasureTopicValue(run='shadow-remember', measure='cover-1', topic='2024-141453', value=0.5),
#  RunMeasureTopicValue(run='battery-frequently', measure='cover-1', topic='2024-34927', value=0.9),
#  RunMeasureTopicValue(run='beginning-french', measure='cover-1', topic='2024-22172', value=0.8),
#  RunMeasureTopicValue(run='cooking-every', measure='cover-1', topic='2024-219563', value=0.8),
#  RunMeasureTopicValue(run='current-scream', measure='cover-1', topic='2024-19562', value=0.8),
#  RunMeasureTopicValue(run='elect-fifth', measure='cover-1', topic='2024-134964', value=0.7),
#  RunMeasureTopicValue(run='honest-darkness', measure='cover-1', topic='2024-113215', value=0.7),
#  RunMeasureTopicValue(run='length-very', measure='cover-1', topic='2024-214467', value=0.6),
#  RunMeasureTopicValue(run='space-traffic', measure='cover-1', topic='2024-217488', value=0.7),
#  RunMeasureTopicValue(run='would-regime', measure='cover-1', topic='2024-223345', value=0.0),
#  RunMeasureTopicValue(run='business-square', measure='cover-1', topic='2024-214483', value=0.5),
#  RunMeasureTopicValue(run='press-wipe', measure='cover-1', topic='2024-32817', value=1.0),
#  RunMeasureTopicValue(run='capacity-indian', measure='cover-1', topic='2024-33513', value=1.0),
#  RunMeasureTopicValue(run='climb-housing', measure='cover-1', topic='2024-129062', value=1.0),
#  RunMeasureTopicValue(run='coat-sequence', measure='cover-1', topic='2024-32817', value=1.0),
#  RunMeasureTopicValue(run='competition-tell', measure='cover-1', topic='2024-33513', value=1.0),
#  RunMeasureTopicValue(run='computer-resource', measure='cover-1', topic='2024-129062', value=1.0),
#  RunMeasureTopicValue(run='concern-read', measure='cover-1', topic='2024-190455', value=0.6),
#  RunMeasureTopicValue(run='crime-road', measure='cover-1', topic='2024-35485', value=1.0),
#  RunMeasureTopicValue(run='develop-space', measure='cover-1', topic='2024-41576', value=0.4),
#  RunMeasureTopicValue(run='proof-hunting', measure='cover-1', topic='2024-41576', value=0.3),
#  RunMeasureTopicValue(run='differ-able', measure='cover-1', topic='2024-28144', value=0.6)]

# %% [markdown]
# ## Leaderboard Plotting code

# %%
import pandas as pd
def leaderboard_to_dataframe(leaderboard):
    out = [(method, mean, stderr)
       for method in leaderboard.keys() if method != "_overall_"
       for mean, stderr in [leaderboard_mean_stderr(leaderboard, method)]
      ]
    return pd.DataFrame(out, columns=['method', 'mean', 'stderr']).set_index('method')

def join_leaderboards(boards: Dict[str,pd.DataFrame], sort_by_board:str):
    data = pd.concat(boards, names=['evals'], axis=1)
    data = data.swaplevel(0,1, axis=1)
    data = data.sort_values(by=("mean",sort_by_board), ascending=False)
    return data

# %%
# convert leaderboards to pandas data frames

df_boards={key:leaderboard_to_dataframe(val) for key,val in boards.items()}
leaderboard_df = join_leaderboards(df_boards, sort_by_board="qrels-ndcg")
leaderboard_df_cover = join_leaderboards(df_boards, sort_by_board="cover-4")

# %%
# export as TSV
leaderboard_df.to_csv(all_leaderboard_file, sep='\t', index=True)

leaderboard_df
# Out:
#                       mean    stderr      mean    stderr      mean    stderr  \
# evals              cover-1   cover-1   cover-4   cover-4   cover-5   cover-5
# method
# ongoing-stare     0.831114  0.009957  0.666337  0.013736  0.208303  0.014404
# suspect-feed      0.847253  0.008794  0.683644  0.012943  0.200000  0.013769
# palm-long-term    0.847253  0.008794  0.683644  0.012943  0.200000  0.013769
# expansion-petrol  0.839558  0.009387  0.671261  0.013874  0.199970  0.014151
# according-useful  0.830323  0.009143  0.678127  0.013316  0.202332  0.013780
# ...                    ...       ...       ...       ...       ...       ...
# pepper-highlight  0.512440  0.016172  0.302658  0.016565  0.068771  0.008618
# beginning-french  0.519319  0.015899  0.301305  0.015778  0.062458  0.007865
# competition-tell  0.487302  0.016248  0.300775  0.016160  0.067442  0.008653
# elect-fifth       0.502980  0.015779  0.293272  0.015728  0.065781  0.007887
# quality-courage   0.498265  0.016369  0.295127  0.015975  0.070764  0.008794
#
#                        mean     stderr      mean    stderr      mean  \
# evals            qrels-ndcg qrels-ndcg   qrels-1   qrels-1   qrels-4
# method
# ongoing-stare      0.606073   0.008094  0.703167  0.008613  0.520667
# suspect-feed       0.599802   0.008194  0.690698  0.010326  0.511628
# palm-long-term     0.599802   0.008194  0.690698  0.010326  0.511628
# expansion-petrol   0.575150   0.007940  0.714950  0.010792  0.486711
# according-useful   0.551936   0.007158  0.582890  0.007452  0.447841
# ...                     ...        ...       ...       ...       ...
# pepper-highlight   0.173946   0.006344  0.127409  0.007296  0.082226
# beginning-french   0.131587   0.003890  0.072425  0.003601  0.050831
# competition-tell   0.131365   0.004339  0.073256  0.003649  0.052159
# elect-fifth        0.128548   0.003721  0.070266  0.003186  0.048671
# quality-courage    0.128189   0.004123  0.071262  0.003520  0.049502
#
#                     stderr      mean    stderr
# evals              qrels-4   qrels-5   qrels-5
# method
# ongoing-stare     0.012178  0.141833  0.011095
# suspect-feed      0.012411  0.129402  0.010296
# palm-long-term    0.012411  0.129402  0.010296
# expansion-petrol  0.011879  0.120764  0.009048
# according-useful  0.010217  0.129568  0.009715
# ...                    ...       ...       ...
# pepper-highlight  0.005669  0.018937  0.002237
# beginning-french  0.002799  0.014784  0.001438
# competition-tell  0.003052  0.015116  0.001741
# elect-fifth       0.002702  0.015449  0.001527
# quality-courage   0.003135  0.016445  0.002014
#
# [93 rows x 14 columns]

# %%
# Compute Min/Max/Med and inter-quartile ranges

quantiles = leaderboard_df.quantile([0.0,0.25, 0.5,0.75,0.85,1.0])

quantiles
# Out:
#            mean    stderr      mean    stderr      mean    stderr       mean  \
# evals   cover-1   cover-1   cover-4   cover-4   cover-5   cover-5 qrels-ndcg
# 0.00   0.405648  0.008568  0.166113  0.011487  0.016611  0.003485   0.128189
# 0.25   0.606157  0.011273  0.393222  0.014459  0.076781  0.008862   0.243855
# 0.50   0.680449  0.013276  0.501440  0.015616  0.111665  0.010981   0.333811
# 0.75   0.768093  0.014711  0.577029  0.016220  0.147508  0.012604   0.410256
# 0.85   0.813585  0.015373  0.653853  0.016525  0.176637  0.013145   0.529308
# 1.00   0.856267  0.019794  0.693751  0.018649  0.210269  0.014404   0.606073
#
#           stderr      mean    stderr      mean    stderr      mean    stderr
# evals qrels-ndcg   qrels-1   qrels-1   qrels-4   qrels-4   qrels-5   qrels-5
# 0.00    0.003721  0.070266  0.003186  0.048671  0.002702  0.010299  0.001438
# 0.25    0.005790  0.199668  0.005346  0.129070  0.005412  0.030066  0.003296
# 0.50    0.006744  0.280565  0.007321  0.207807  0.007074  0.048007  0.005018
# 0.75    0.008194  0.423920  0.009919  0.282558  0.009866  0.071927  0.006059
# 0.85    0.008695  0.569070  0.010597  0.424618  0.010841  0.114551  0.008978
# 1.00    0.012233  0.714950  0.017042  0.520667  0.015994  0.141833  0.011095

# %%
# Plot leaderboards with stderror

from matplotlib.lines import Line2D
import pathlib as path

def plot_leaderboard(leaderboard_df, file_ext=''):
    leaderboard_df.index =  leaderboard_df.index.astype(str).fillna("Unknown") 
    
    ax=leaderboard_df.plot.line(y='mean', yerr='stderr', color=["#ffaaaa", "#ff0000", "#ff7777", "#00aaaa", "#aaaaff", "#0000ff", "#7777ff" ],alpha=0.5, figsize=(12,6))
    ax.tick_params(axis='x', rotation=90, labelsize='small')
    ax.set_xticks(range(len(leaderboard_df)))
    ax.set_xticklabels(leaderboard_df.index, rotation=90, fontsize='small')
   
    quantiles = leaderboard_df.quantile([0.0,0.1, 0.5,0.75,0.85,1.0])
    
    data = leaderboard_df
    custom_legend = [Line2D([0], [0],  linestyle='None', marker='o', color='green',  label='> 85%')
                     , Line2D([0], [0],  linestyle='None', marker='.', color='green',  label='> 75%')]

  
    ax.legend(handles=custom_legend + ax.get_legend_handles_labels()[0], loc='upper left',bbox_to_anchor=(1.0, 1.0))
    
    for column in data.columns:
       if column[0]=="mean":
        ax.scatter(data.index, data[column].where(data[column] > quantiles.loc[0.85,column]), 
                   color='green', label=f"{column} > 85%", marker='o')
        ax.scatter(data.index, data[column].where(data[column] > quantiles.loc[0.75,column]), 
                   color='green', label=f"{column} > 75%", marker='.')
    
    
    fig = ax.get_figure()
    plot_file1 = rubric_final.with_name(f"{rubric_final.stem}_plot").with_suffix(f".leaderboard-plot{file_ext}.png")
    z = fig.savefig(plot_file1, dpi=300, bbox_inches='tight')
    
    fig = ax.get_figure()
    plot_file2 = rubric_final.with_name(f"{rubric_final.stem}_plot").with_suffix(f".leaderboard-plot{file_ext}.svg")
    z = fig.savefig(plot_file2, dpi=300, bbox_inches='tight')
    
    
    fig = ax.get_figure()
    plot_file3 = rubric_final.with_name(f"{rubric_final.stem}_plot").with_suffix(f".leaderboard-plot{file_ext}.pdf")
    z = fig.savefig(plot_file3, dpi=300, bbox_inches='tight')

    return fig, plot_file1, plot_file2, plot_file3

# %%
# Plot sorted by qrels-ndcg
fig, plot_file1, plot_file2, plot_file3 = plot_leaderboard(leaderboard_df, "")

# %%
# Plot sorted by cover-4
fig, plot_file1x, plot_file2x, plot_file3x = plot_leaderboard(leaderboard_df_cover, "-cover4")

# %%
archive
# Out:
# PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.results.tar.gz')

# %%
# produce an archive of RUBRIC analysis result files for distribution

import subprocess

readme = DATA/"README.mkd"
subprocess.run(["tar","-czf",archive, runs,qrels, export_file, all_leaderboard_file, plot_file1, plot_file2, plot_file3, plot_file1x, plot_file2x, plot_file3x, readme])
# Out:
# CompletedProcess(args=['tar', '-czf', PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.results.tar.gz'), PosixPath('data/questions-rate--rubric-rag24-gen.jsonl-runs'), PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.qrel'), PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.export.tsv'), PosixPath('data/questions-rate--rubric-rag24-gen.jsonl.leaderboard.tsv'), PosixPath('data/questions-rate--rubric-rag24-gen.leaderboard-plot.png'), PosixPath('data/questions-rate--rubric-rag24-gen.leaderboard-plot.svg'), PosixPath('data/questions-rate--rubric-rag24-gen.leaderboard-plot.pdf'), PosixPath('data/questions-rate--rubric-rag24-gen.leaderboard-plot-cover4.png'), PosixPath('data/questions-rate--rubric-rag24-gen.leaderboard-plot-cover4.svg'), PosixPath('data/questions-rate--rubric-rag24-gen.leaderboard-plot-cover4.pdf'), PosixPath('data/README.mkd')], returncode=0)

# %% [markdown]
# # Analysis of Individual Systems
#
# You can skip this section.
#
# Choose queries (topics) and systems (runs) and display the retrieved/generated passages with positively graded rubric-questions.

# %%
# div_method1="pilot-competitor"
div_method1="tremendous-whatever"
minlevel=4

# inspect results
for result in examgrades[0:1]: # just first query
  # if result.queryId=="2024-111506":  # a particular query
    queryId=result.queryId
    paragraphs=result.paragraphs
    print(f"query = {result.queryId} / run = {div_method1}")

    correctly_answered=set()
    for paragraph in paragraphs:  # just first ten paragraphs
        paragraph_id = paragraph.paragraph_id
        text = paragraph.text
        rankings = paragraph.paragraph_data.rankings if paragraph.paragraph_data else [] # which system retrieved this paragraph?

        method1_rankings=[ r for r in rankings if r.method==div_method1 ]
        if (method1_rankings):
            rank = method1_rankings[0].rank
            if rank <= 20:
                print("\n")
                print("rank", rank)
                # print(paragraph_id)
                print(text)
                for grades in paragraph.exam_grades:
                    # self_ratings are the numerical grade (0-5) for each question-style nugget
                    # answers are the raw output we received from the grading LLM
                    for index, (r, a) in enumerate(zip(grades.self_ratings, grades.answers)): 
                        if r.self_rating >= minlevel:
                            print(f"Q{index+1}({r.self_rating})")
                            correctly_answered.add(f"Q{index+1}")
                            # print(index, r.question_id, r.self_rating)
                    print("-")
    print(f"correctly answered: {correctly_answered}")
# Out:
# query = 2024-145979 / run = tremendous-whatever
#
#
# rank 1
# Vicarious trauma, also known as secondary trauma or compassion fatigue, is a condition that occurs when an individual experiences emotional and psychological distress as a result of being exposed to the traumatic experiences of others.
# Q5(4)
# -
#
#
# rank 2
# This can happen to anyone who works with or supports people who have experienced trauma, such as mental health professionals, social workers, first responders, and caregivers.
# Q4(4)
# Q8(4)
# -
#
#
# rank 3
#  Vicarious trauma can manifest in various ways, including:  * Emotional numbing or desensitization * Increased anxiety, stress, or hypervigilance *
# Q1(4)
# Q4(4)
# Q5(4)
# -
#
#
# rank 4
# Intrusive
# -
#
#
# rank 5
# thoughts
# -
#
#
# rank 6
# or
# -
#
#
# rank 7
# images related to the traumatic event
# -
#
#
# rank 8
# * Avoidance of triggers or reminders of the traumatic event * Changes in worldview or sense of safety * Physical symptoms such as headaches or gastrointestinal problems  Coping with vicarious trauma requires a combination of self-care, boundary-setting, and support.
# Q1(4)
# Q3(4)
# Q4(4)
# Q5(4)
# Q7(4)
# Q10(4)
# -
#
#
# rank 9
# Here are some strategies that can help:  * Practice self-care: Engage in activities that promote relaxation and stress reduction, such as exercise, meditation, or yoga.
# Q3(4)
# Q10(4)
# -
#
#
# rank 10
# * Set boundaries: Establish clear limits on your work and personal life to prevent burnout and maintain a healthy work-life balance.
# -
#
#
# rank 11
# * Seek support: Connect with colleagues, friends, or a therapist who can provide emotional support and guidance.
# Q3(4)
# Q5(4)
# Q10(4)
# -
#
#
# rank 12
# * Engage in debriefing: Participate in regular debriefing sessions with colleagues or a supervisor to process and reflect on traumatic experiences.
# Q3(4)
# Q10(4)
# -
#
#
# rank 13
# * Prioritize sleep and nutrition: Maintain a healthy lifestyle to reduce stress and promote resilience.
# Q3(4)
# -
#
#
# rank 14
# * Consider therapy: Seek professional help if symptoms persist or worsen over time.  It's essential to recognize that vicarious trauma is a common and treatable condition.
# Q4(4)
# Q5(5)
# Q10(4)
# -
#
#
# rank 15
# By acknowledging the risks and taking proactive steps to manage stress and promote self-care, individuals can reduce their risk of developing vicarious trauma and maintain their emotional well-being.
# Q5(4)
# Q7(5)
# -
# correctly answered: {'Q8', 'Q10', 'Q4', 'Q1', 'Q5', 'Q3', 'Q7'}
